# %% [markdown]
# # Preprocessing LinkedIn Data Jobs Dataset Folder

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
id = '18U6rB-OoH4ZvgGBF2V8nVUDMyDtD1dCQ'
url = f'https://drive.google.com/uc?id={id}'
df = pd.read_csv(url)
df.head()
# Out:
#    id            title    company           location  \
# 0   1     Data Analyst       Meta       New York, NY
# 1   2     Data Analyst       Meta  San Francisco, CA
# 2   3     Data Analyst       Meta    Los Angeles, CA
# 3   4     Data Analyst       Meta     Washington, DC
# 4   5  Data Analyst II  Pinterest        Chicago, IL
#
#                                                 link    source date_posted  \
# 0  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14
# 1  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14
# 2  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14
# 3  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14
# 4  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-16
#
#    work_type  employment_type  \
# 0        NaN              NaN
# 1        NaN              NaN
# 2        NaN              NaN
# 3        NaN              NaN
# 4        NaN              NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1048 non-null   int64
#  1   title            1048 non-null   object
#  2   company          1046 non-null   object
#  3   location         1033 non-null   object
#  4   link             1048 non-null   object
#  5   source           959 non-null    object
#  6   date_posted      1025 non-null   object
#  7   work_type        0 non-null      float64
#  8   employment_type  0 non-null      float64
#  9   description      1044 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 82.0+ KB

# %%
df.columns
# Out:
# Index(['id', 'title', 'company', 'location', 'link', 'source', 'date_posted',
#        'work_type', 'employment_type', 'description'],
#       dtype='object')

# %%
df.drop(columns=['id', 'company', 'location', 'link', 'source',
       'work_type', 'employment_type'], inplace=True)
df.head()
# Out:
#              title date_posted  \
# 0     Data Analyst  2025-04-14
# 1     Data Analyst  2025-04-14
# 2     Data Analyst  2025-04-14
# 3     Data Analyst  2025-04-14
# 4  Data Analyst II  2025-04-16
#
#                                          description
# 0  The Social Measurement team is a growing team ...
# 1  The Social Measurement team is a growing team ...
# 2  The Social Measurement team is a growing team ...
# 3  The Social Measurement team is a growing team ...
# 4  About Pinterest\n\nMillions of people around t...

# %%
# Proses data null + duplicate
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        1048 non-null   object
#  1   date_posted  1025 non-null   object
#  2   description  1044 non-null   object
# dtypes: object(3)
# memory usage: 24.7+ KB

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 929 entries, 0 to 1047
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        929 non-null    object
#  1   date_posted  929 non-null    object
#  2   description  929 non-null    object
# dtypes: object(3)
# memory usage: 29.0+ KB

# %%
# Role Normalization

def map_role(title):
    title = title.lower()
    
    if 'data analyst' in title:
        return 'data analyst'
    elif 'frontend' in title or 'front end' in title or 'react' in title or 'front-end' in title:
        return 'frontend'
    elif "backend" in title or 'back end' in title or "node" in title or 'back-end' in title:
        return "backend"
    else:
        return None
df['role'] = df['title'].apply(map_role)
df = df[df['role'].notnull()].copy()
df
# Out:
#                                                   title date_posted  \
# 0                                          Data Analyst  2025-04-14
# 2                                          Data Analyst  2025-04-14
# 4                                       Data Analyst II  2025-04-16
# 5                                          Data Analyst  2025-04-11
# 6     Data Analyst, Production Finance Operations & ...  2025-04-10
# ...                                                 ...         ...
# 911                                     Data Analyst II  2025-06-04
# 914                         Data Analyst - Construction  2025-06-06
# 925                                 Senior Data Analyst  2025-06-09
# 1003                                       Data Analyst  2025-06-09
# 1015                                Junior Data Analyst  2025-06-04
#
#                                             description          role
# 0     The Social Measurement team is a growing team ...  data analyst
# ...

# %%
import re

def casefolding(text):
    return text.lower()

def cleaning(text):
    text = re.sub(r"http\S+", "", text)
    
    text = text.replace('\n', ' ')
    text = text.replace('*','')
    text = text.replace('-','')
    
    text = text.strip()
    
    text = re.sub(r'\s+', ' ', text)
    
    return text


df['clean_title'] = df['title'].apply(casefolding)
df['clean_title'] = df['clean_title'].apply(cleaning)

df['clean_description'] = df['description'].apply(casefolding)
df['clean_description'] = df['clean_description'].apply(cleaning)

# %%
df
# Out:
#                                                   title date_posted  \
# 0                                          Data Analyst  2025-04-14
# 2                                          Data Analyst  2025-04-14
# 4                                       Data Analyst II  2025-04-16
# 5                                          Data Analyst  2025-04-11
# 6     Data Analyst, Production Finance Operations & ...  2025-04-10
# ...                                                 ...         ...
# 911                                     Data Analyst II  2025-06-04
# 914                         Data Analyst - Construction  2025-06-06
# 925                                 Senior Data Analyst  2025-06-09
# 1003                                       Data Analyst  2025-06-09
# 1015                                Junior Data Analyst  2025-06-04
#
#                                             description          role  \
# 0     The Social Measurement team is a growing team ...  data analyst
# ...

# %%
def remove_irrelevant_sections(text):
    irrelevant_keywords = [
        "equal employment",
        "affirmative action",
        "we do not discriminate",
        "about meta",
        "compensation",
        "benefits",
        "-verify",
        "accomodations"
        "about us"
    ]
    
    for keyword in irrelevant_keywords:
        pattern = re.compile(rf"{keyword}.*", re.IGNORECASE)
        text = pattern.sub("", text)
    
    return text
df['clean_description'] = df['clean_description'].apply(remove_irrelevant_sections)

# %%
df
# Out:
#                                                   title date_posted  \
# 0                                          Data Analyst  2025-04-14
# 2                                          Data Analyst  2025-04-14
# 4                                       Data Analyst II  2025-04-16
# 5                                          Data Analyst  2025-04-11
# 6     Data Analyst, Production Finance Operations & ...  2025-04-10
# ...                                                 ...         ...
# 911                                     Data Analyst II  2025-06-04
# 914                         Data Analyst - Construction  2025-06-06
# 925                                 Senior Data Analyst  2025-06-09
# 1003                                       Data Analyst  2025-06-09
# 1015                                Junior Data Analyst  2025-06-04
#
#                                             description          role  \
# 0     The Social Measurement team is a growing team ...  data analyst
# ...

# %%
df['role'].value_counts()
# Out:
# role
# data analyst    251
# frontend          3
# Name: count, dtype: int64

# %%
df_final = df[['role', 'clean_description']].copy()
df_final
# Out:
#               role                                  clean_description
# 0     data analyst  the social measurement team is a growing team ...
# 2     data analyst  the social measurement team is a growing team ...
# 4     data analyst  about pinterest millions of people around the ...
# 5     data analyst  about fanduel fanduel group is the premier mob...
# 6     data analyst  netflix is one of the world's leading entertai...
# ...            ...                                                ...
# 911   data analyst  the role job description we are seeking a data...
# 914   data analyst
# 925   data analyst  about us smith.ai builds ai voice agents that ...
# 1003  data analyst  we’re looking for a real estate data analyst t...
# 1015  data analyst  mantech seeks a motivated, career\ and custome...
#
# [254 rows x 2 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, 0 to 1015
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   role               254 non-null    object
#  1   clean_description  254 non-null    object
# dtypes: object(2)
# memory usage: 6.0+ KB

# %%
df_final.rename(columns={'clean_description': 'description'}, inplace=True)
df_final
# Out:
#               role                                        description
# 0     data analyst  the social measurement team is a growing team ...
# 2     data analyst  the social measurement team is a growing team ...
# 4     data analyst  about pinterest millions of people around the ...
# 5     data analyst  about fanduel fanduel group is the premier mob...
# 6     data analyst  netflix is one of the world's leading entertai...
# ...            ...                                                ...
# 911   data analyst  the role job description we are seeking a data...
# 914   data analyst
# 925   data analyst  about us smith.ai builds ai voice agents that ...
# 1003  data analyst  we’re looking for a real estate data analyst t...
# 1015  data analyst  mantech seeks a motivated, career\ and custome...
#
# [254 rows x 2 columns]

# %%
df_final['description'] = df_final['description'].astype(str).str.strip()
df_final
# Out:
#               role                                        description
# 0     data analyst  the social measurement team is a growing team ...
# 2     data analyst  the social measurement team is a growing team ...
# 4     data analyst  about pinterest millions of people around the ...
# 5     data analyst  about fanduel fanduel group is the premier mob...
# 6     data analyst  netflix is one of the world's leading entertai...
# ...            ...                                                ...
# 911   data analyst  the role job description we are seeking a data...
# 914   data analyst
# 925   data analyst  about us smith.ai builds ai voice agents that ...
# 1003  data analyst  we’re looking for a real estate data analyst t...
# 1015  data analyst  mantech seeks a motivated, career\ and custome...
#
# [254 rows x 2 columns]

# %%
import numpy as np
df_final['skills'] = np.nan
df_final
# Out:
#               role                                        description  skills
# 0     data analyst  the social measurement team is a growing team ...     NaN
# 2     data analyst  the social measurement team is a growing team ...     NaN
# 4     data analyst  about pinterest millions of people around the ...     NaN
# 5     data analyst  about fanduel fanduel group is the premier mob...     NaN
# 6     data analyst  netflix is one of the world's leading entertai...     NaN
# ...            ...                                                ...     ...
# 911   data analyst  the role job description we are seeking a data...     NaN
# 914   data analyst                                                        NaN
# 925   data analyst  about us smith.ai builds ai voice agents that ...     NaN
# 1003  data analyst  we’re looking for a real estate data analyst t...     NaN
# 1015  data analyst  mantech seeks a motivated, career\ and custome...     NaN
#
# [254 rows x 3 columns]

# %%
df_final.to_csv('data5.csv', index=False)
