# %% [markdown]
# # Preprocessing Data Science Job Posting Folder

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## File job_postings

# %%
id_jp = '1p481647dpU6EraGDw0zCnfH-2F3OReEC'
url_jp = f'https://drive.google.com/uc?id={id_jp}'
df_jp = pd.read_csv(url_jp)
df_jp.head()
# Out:
#                                             job_link  \
# 0  https://www.linkedin.com/jobs/view/senior-mach...
# 1  https://www.linkedin.com/jobs/view/principal-s...
# 2  https://www.linkedin.com/jobs/view/senior-etl-...
# 3  https://www.linkedin.com/jobs/view/senior-data...
# 4  https://www.linkedin.com/jobs/view/lead-data-e...
#
#              last_processed_time   last_status got_summary got_ner  \
# 0  2024-01-21 08:08:48.031964+00  Finished NER           t       t
# 1  2024-01-20 04:02:12.331406+00  Finished NER           t       t
# 2  2024-01-21 08:08:31.941595+00  Finished NER           t       t
# 3  2024-01-20 15:30:55.796572+00  Finished NER           t       t
# 4  2024-01-21 08:08:58.312124+00  Finished NER           t       t
#
#   is_being_worked                                     job_title  \
# 0               f              Senior Machine Learning Engineer
# 1               f  Principal Software Engineer, ML Accelerators
# ...

# %%
df_jp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12217 entries, 0 to 12216
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_link             12217 non-null  object
#  1   last_processed_time  12217 non-null  object
#  2   last_status          12217 non-null  object
#  3   got_summary          12217 non-null  object
#  4   got_ner              12217 non-null  object
#  5   is_being_worked      12217 non-null  object
#  6   job_title            12217 non-null  object
#  7   company              12217 non-null  object
#  8   job_location         12216 non-null  object
#  9   first_seen           12217 non-null  object
#  10  search_city          12217 non-null  object
#  11  search_country       12217 non-null  object
#  12  search_position      12217 non-null  object
#  13  job_level            12217 non-null  object
#  14  job_type             12217 non-null  object
# ...

# %%
df_jp.columns
# Out:
# Index(['job_link', 'last_processed_time', 'last_status', 'got_summary',
#        'got_ner', 'is_being_worked', 'job_title', 'company', 'job_location',
#        'first_seen', 'search_city', 'search_country', 'search_position',
#        'job_level', 'job_type'],
#       dtype='object')

# %%
# Drop kolom
df_jp.drop(columns=['last_processed_time', 'last_status', 'got_summary',
       'got_ner', 'is_being_worked', 'company', 'job_location',
       'first_seen', 'search_city', 'search_country', 'job_type'], inplace=True)

df_jp
# Out:
#                                                 job_link  \
# 0      https://www.linkedin.com/jobs/view/senior-mach...
# 1      https://www.linkedin.com/jobs/view/principal-s...
# 2      https://www.linkedin.com/jobs/view/senior-etl-...
# 3      https://www.linkedin.com/jobs/view/senior-data...
# 4      https://www.linkedin.com/jobs/view/lead-data-e...
# ...                                                  ...
# 12212  https://uk.linkedin.com/jobs/view/data-reporti...
# 12213  https://www.linkedin.com/jobs/view/corporate-a...
# 12214  https://www.linkedin.com/jobs/view/senior-data...
# 12215  https://www.linkedin.com/jobs/view/senior-data...
# 12216  https://www.linkedin.com/jobs/view/medical-tec...
#
#                                           job_title  \
# 0                  Senior Machine Learning Engineer
# 1      Principal Software Engineer, ML Accelerators
# 2              Senior ETL Data Warehouse Specialist
# 3       Senior Data Warehouse Developer / Architect
# ...

# %%
# drop duplicate `job_link`
df_jp.drop_duplicates(subset='job_link', inplace=True)
df_jp.dropna(inplace=True)

# %%
#strip whitespace + lowercase
import re

def casefolding(text):
    return text.lower()

def cleaning(text):
    text = re.sub(r"http\S+", "", text)
    
    text = text.replace('\n', ' ')
    text = text.replace('*','')
    
    text = text.strip()
    
    text = re.sub(r'\s+', ' ', text)
    
    return text

for col in df_jp.columns:
    if col == 'job_link':
        pass
    else:
        df_jp.loc[:, f"clean_{col}"] = df_jp[col].apply(casefolding)
        df_jp.loc[:, f"clean_{col}"] = df_jp[f"clean_{col}"].apply(cleaning)
df_jp
# Out:
#                                                 job_link  \
# 0      https://www.linkedin.com/jobs/view/senior-mach...
# 1      https://www.linkedin.com/jobs/view/principal-s...
# 2      https://www.linkedin.com/jobs/view/senior-etl-...
# 3      https://www.linkedin.com/jobs/view/senior-data...
# 4      https://www.linkedin.com/jobs/view/lead-data-e...
# ...                                                  ...
# 12212  https://uk.linkedin.com/jobs/view/data-reporti...
# 12213  https://www.linkedin.com/jobs/view/corporate-a...
# 12214  https://www.linkedin.com/jobs/view/senior-data...
# 12215  https://www.linkedin.com/jobs/view/senior-data...
# 12216  https://www.linkedin.com/jobs/view/medical-tec...
#
#                                           job_title  \
# 0                  Senior Machine Learning Engineer
# 1      Principal Software Engineer, ML Accelerators
# 2              Senior ETL Data Warehouse Specialist
# 3       Senior Data Warehouse Developer / Architect
# ...

# %% [markdown]
# ## File job_skills

# %%
id_js = '1v57BXUB_JQF0b3YwrkcJeRL6bDRXbQpC'
url_js = f'https://drive.google.com/uc?id={id_js}'
df_js = pd.read_csv(url_js)
df_js.head()
# Out:
#                                             job_link  \
# 0  https://www.linkedin.com/jobs/view/senior-mach...
# 1  https://www.linkedin.com/jobs/view/principal-s...
# 2  https://www.linkedin.com/jobs/view/senior-etl-...
# 3  https://www.linkedin.com/jobs/view/senior-data...
# 4  https://www.linkedin.com/jobs/view/lead-data-e...
#
#                                           job_skills
# 0  Machine Learning, Programming, Python, Scala, ...
# 1  C++, Python, PyTorch, TensorFlow, MXNet, CUDA,...
# 2  ETL, Data Integration, Data Transformation, Da...
# 3  Data Lakes, Data Bricks, Azure Data Factory Pi...
# 4  Java, Scala, Python, RDBMS, NoSQL, Redshift, S...

# %%
df_js.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12217 entries, 0 to 12216
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   job_link    12217 non-null  object
#  1   job_skills  12212 non-null  object
# dtypes: object(2)
# memory usage: 191.0+ KB

# %%
df_js.columns
# Out:
# Index(['job_link', 'job_skills'], dtype='object')

# %%
# drop duplicate `job_link`
df_js.drop_duplicates(subset='job_link', inplace=True)
df_js.dropna(inplace=True)

# %%
#strip whitespace + lowercase
import re

def casefolding(text):
    return text.lower()

def cleaning(text):
    text = re.sub(r"http\S+", "", text)
    
    text = text.replace('\n', ' ')
    text = text.replace('*','')
    
    text = text.strip()
    
    text = re.sub(r'\s+', ' ', text)
    
    return text

df_js['clean_job_skills'] = df_js['job_skills'].apply(casefolding)
df_js['clean_job_skills'] = df_js['clean_job_skills'].apply(cleaning)
df_js
# Out:
#                                                 job_link  \
# 0      https://www.linkedin.com/jobs/view/senior-mach...
# 1      https://www.linkedin.com/jobs/view/principal-s...
# 2      https://www.linkedin.com/jobs/view/senior-etl-...
# 3      https://www.linkedin.com/jobs/view/senior-data...
# 4      https://www.linkedin.com/jobs/view/lead-data-e...
# ...                                                  ...
# 12212  https://uk.linkedin.com/jobs/view/data-reporti...
# 12213  https://www.linkedin.com/jobs/view/corporate-a...
# 12214  https://www.linkedin.com/jobs/view/senior-data...
# 12215  https://www.linkedin.com/jobs/view/senior-data...
# 12216  https://www.linkedin.com/jobs/view/medical-tec...
#
#                                               job_skills  \
# 0      Machine Learning, Programming, Python, Scala, ...
# 1      C++, Python, PyTorch, TensorFlow, MXNet, CUDA,...
# 2      ETL, Data Integration, Data Transformation, Da...
# ...

# %% [markdown]
# ## Join File

# %%
# job_link (INNER JOIN)
df = pd.merge(df_jp, df_js, on='job_link', how='inner')
df
# Out:
#                                                 job_link  \
# 0      https://www.linkedin.com/jobs/view/senior-mach...
# 1      https://www.linkedin.com/jobs/view/principal-s...
# 2      https://www.linkedin.com/jobs/view/senior-etl-...
# 3      https://www.linkedin.com/jobs/view/senior-data...
# 4      https://www.linkedin.com/jobs/view/lead-data-e...
# ...                                                  ...
# 12207  https://uk.linkedin.com/jobs/view/data-reporti...
# 12208  https://www.linkedin.com/jobs/view/corporate-a...
# 12209  https://www.linkedin.com/jobs/view/senior-data...
# 12210  https://www.linkedin.com/jobs/view/senior-data...
# 12211  https://www.linkedin.com/jobs/view/medical-tec...
#
#                                           job_title  \
# 0                  Senior Machine Learning Engineer
# 1      Principal Software Engineer, ML Accelerators
# 2              Senior ETL Data Warehouse Specialist
# 3       Senior Data Warehouse Developer / Architect
# ...

# %%
# Proses data null + duplicate
# Role Normalization

def map_role(title):
    title = title.lower()
    
    if 'data analyst' in title:
        return 'data analyst'
    elif 'frontend' in title or 'front end' in title or 'react' in title or 'front-end' in title:
        return 'frontend'
    elif "backend" in title or 'back end' in title or "node" in title or 'back-end' in title:
        return "backend"
    else:
        return None
df['role'] = df['job_title'].apply(map_role)
df = df[df['role'].notnull()].copy()
df
# Out:
#                                                 job_link  \
# 8      https://www.linkedin.com/jobs/view/senior-fina...
# 10     https://www.linkedin.com/jobs/view/sr-workforc...
# 16     https://ca.linkedin.com/jobs/view/data-analyst...
# 20     https://www.linkedin.com/jobs/view/contractor-...
# 28     https://www.linkedin.com/jobs/view/vcp-design-...
# ...                                                  ...
# 12100  https://www.linkedin.com/jobs/view/sc-master-d...
# 12127  https://www.linkedin.com/jobs/view/contractor-...
# 12134  https://uk.linkedin.com/jobs/view/senior-backe...
# 12141  https://www.linkedin.com/jobs/view/senior-data...
# 12147  https://www.linkedin.com/jobs/view/data-analys...
#
#                                                job_title  \
# 8                          Senior Financial Data Analyst
# 10                 Sr. Workforce Management Data Analyst
# 16                                Data Analyst Part Time
# ...

# %%
df['role'].value_counts()
# Out:
# role
# data analyst    1888
# backend           19
# frontend           5
# Name: count, dtype: int64

# %%
df_final = df[['role', 'clean_job_skills', ]].copy()
df_final
# Out:
#                role                                   clean_job_skills
# 8      data analyst  problem solving, data analysis, predictive ana...
# 10     data analyst  sql, database administration, advanced statist...
# 16     data analyst  data analysis, data visualization, statistical...
# 20     data analyst  revenue cycle, healthcare data analysis, data ...
# 28     data analyst  variable cost productivity, data analytics, co...
# ...             ...                                                ...
# 12100  data analyst  sap, parameters, mps, mrp, supply chain flow, ...
# 12127  data analyst  revenue cycle, healthcare data, data analysis,...
# 12134       backend  python, django, postgres, pubsub, kubernetes, ...
# 12141  data analyst  data analytics, data insights, tableau, power ...
# 12147  data analyst  data analytics, data visualization, spotfire, ...
#
# [1912 rows x 2 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1912 entries, 8 to 12147
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   role              1912 non-null   object
#  1   clean_job_skills  1912 non-null   object
# dtypes: object(2)
# memory usage: 44.8+ KB

# %%
df_final.rename(columns={'clean_job_skills': 'skills'}, inplace=True)
df_final
# Out:
#                role                                             skills
# 8      data analyst  problem solving, data analysis, predictive ana...
# 10     data analyst  sql, database administration, advanced statist...
# 16     data analyst  data analysis, data visualization, statistical...
# 20     data analyst  revenue cycle, healthcare data analysis, data ...
# 28     data analyst  variable cost productivity, data analytics, co...
# ...             ...                                                ...
# 12100  data analyst  sap, parameters, mps, mrp, supply chain flow, ...
# 12127  data analyst  revenue cycle, healthcare data, data analysis,...
# 12134       backend  python, django, postgres, pubsub, kubernetes, ...
# 12141  data analyst  data analytics, data insights, tableau, power ...
# 12147  data analyst  data analytics, data visualization, spotfire, ...
#
# [1912 rows x 2 columns]

# %%
def preprocessing_lanjutan(text):
    text = text.replace('/', ' ')
    text = text.replace('&', ' ')
    text = re.sub(r"[()]", " ", text)
    
    return text
    
df_final['skills'] = df_final['skills'].apply(preprocessing_lanjutan).copy()
df_final
# Out:
#                role                                             skills
# 8      data analyst  problem solving, data analysis, predictive ana...
# 10     data analyst  sql, database administration, advanced statist...
# 16     data analyst  data analysis, data visualization, statistical...
# 20     data analyst  revenue cycle, healthcare data analysis, data ...
# 28     data analyst  variable cost productivity, data analytics, co...
# ...             ...                                                ...
# 12100  data analyst  sap, parameters, mps, mrp, supply chain flow, ...
# 12127  data analyst  revenue cycle, healthcare data, data analysis,...
# 12134       backend  python, django, postgres, pubsub, kubernetes, ...
# 12141  data analyst  data analytics, data insights, tableau, power ...
# 12147  data analyst  data analytics, data visualization, spotfire, ...
#
# [1912 rows x 2 columns]

# %%
import numpy as np
df_final['description'] = np.nan
df_final
# Out:
#                role                                             skills  \
# 8      data analyst  problem solving, data analysis, predictive ana...
# 10     data analyst  sql, database administration, advanced statist...
# 16     data analyst  data analysis, data visualization, statistical...
# 20     data analyst  revenue cycle, healthcare data analysis, data ...
# 28     data analyst  variable cost productivity, data analytics, co...
# ...             ...                                                ...
# 12100  data analyst  sap, parameters, mps, mrp, supply chain flow, ...
# 12127  data analyst  revenue cycle, healthcare data, data analysis,...
# 12134       backend  python, django, postgres, pubsub, kubernetes, ...
# 12141  data analyst  data analytics, data insights, tableau, power ...
# 12147  data analyst  data analytics, data visualization, spotfire, ...
#
#        description
# 8              NaN
# 10             NaN
# 16             NaN
# 20             NaN
# ...

# %%
df_final.to_csv('data1.csv', index=False)
