# %% [markdown]
# # Preprocessing Internshala Jobs Dataset Folder

# %% [markdown]
# ## Alur (Belum Fix)
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
id = '1aOvtU7cv-7lVE4GPIe6fEmF2SjJaCDoO'
url = f'https://drive.google.com/uc?id={id}'
df = pd.read_csv(url)
df.head()
# Out:
#                    Company_Name                                   JobTitles  \
# 0                  Bauer Bodoni                WordPress Development Intern
# 1                  Bauer Bodoni                WordPress Development Intern
# 2  ESSI Integrated Technologies               ERPNext And HRMS Admin Intern
# 3               Growify Digital                    Website Operation Intern
# 4                    Confluencr  Influencer Marketing Data Analytics Intern
#
#                                               Skills  \
# 0                                          WordPress
# 1                          MS-PowerPoint , WordPress
# 2  Accounting , Enterprise Resource Planning(ERP)...
# 3                             JavaScript , WordPress
# 4  Digital Advertising , English Proficiency (Spo...
#
#                                          Description                 Stipend  \
# 0  Are you a WordPress whiz looking to gain hands...  ₹ 15,000-20,000 /month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  431 non-null    object
#  1   JobTitles     431 non-null    object
#  2   Skills        431 non-null    object
#  3   Description   431 non-null    object
#  4   Stipend       431 non-null    object
#  5   Links         431 non-null    object
# dtypes: object(6)
# memory usage: 20.3+ KB

# %%
df.columns
# Out:
# Index(['Company_Name', 'JobTitles', 'Skills', 'Description', 'Stipend',
#        'Links'],
#       dtype='object')

# %%
df.drop(columns=['Company_Name', 'Stipend', 'Links'], inplace=True)
df.head()
# Out:
#                                     JobTitles  \
# 0                WordPress Development Intern
# 1                WordPress Development Intern
# 2               ERPNext And HRMS Admin Intern
# 3                    Website Operation Intern
# 4  Influencer Marketing Data Analytics Intern
#
#                                               Skills  \
# 0                                          WordPress
# 1                          MS-PowerPoint , WordPress
# 2  Accounting , Enterprise Resource Planning(ERP)...
# 3                             JavaScript , WordPress
# 4  Digital Advertising , English Proficiency (Spo...
#
#                                          Description
# 0  Are you a WordPress whiz looking to gain hands...
# 1  As a WordPress Development intern at Bauer Bod...
# 2  Selected intern's day-to-day responsibilities ...
# 3  Selected intern's day-to-day responsibilities ...
# 4  Selected intern's day-to-day responsibilities ...

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   JobTitles    431 non-null    object
#  1   Skills       431 non-null    object
#  2   Description  431 non-null    object
# dtypes: object(3)
# memory usage: 10.2+ KB

# %%
# Role Normalization

def map_role(title):
    title = title.lower()
    
    if 'data analyst' in title:
        return 'data analyst'
    elif 'frontend' in title or 'front end' in title or 'react' in title or 'front-end' in title:
        return 'frontend'
    elif "backend" in title or 'back end' in title or "node" in title or 'back-end' in title:
        return "backend"
    else:
        return None
df['role'] = df['JobTitles'].apply(map_role)
df = df[df['role'].notnull()].copy()
df
# Out:
#                                              JobTitles  \
# 22                          Backend Development Intern
# 24                        Front End Development Intern
# 36   Frontend Development + Technical Content Writi...
# 37       Reactjs Development Intern (Part time/Remote)
# 38          React Native App Developer Intern (Remote)
# ..                                                 ...
# 421                         Reactjs Development Intern
# 422                         Node.js Development Intern
# 425              Front End Development Intern (Remote)
# 426                       Front End Development Intern
# 427           React Native Development Intern (Remote)
#
#                                                 Skills  \
# 22   Amazon Web Server (AWS) , Hadoop , MySQL , Python
# 24                  CSS , HTML , HTML&CSS , JavaScript
# 36           JavaScript , Node.js , React , TypeScript
# 37        Figma , GitHub , HTML , JavaScript , ReactJS
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, 22 to 427
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   JobTitles    61 non-null     object
#  1   Skills       61 non-null     object
#  2   Description  61 non-null     object
#  3   role         61 non-null     object
# dtypes: object(4)
# memory usage: 2.4+ KB

# %%
import re

def casefolding(text):
    return text.lower()

def cleaning(text):
    text = re.sub(r"http\S+", "", text)
    
    text = text.replace('\n', ' ')
    text = text.replace('*','')
    
    text = text.strip()
    
    text = re.sub(r'\s+', ' ', text)
    
    return text

for col in df.columns:
    df.loc[:, f"clean_{col}"] = df[col].apply(casefolding)
    df.loc[:, f"clean_{col}"] = df[f"clean_{col}"].apply(cleaning)
df
# Out:
#                                              JobTitles  \
# 22                          Backend Development Intern
# 24                        Front End Development Intern
# 36   Frontend Development + Technical Content Writi...
# 37       Reactjs Development Intern (Part time/Remote)
# 38          React Native App Developer Intern (Remote)
# ..                                                 ...
# 421                         Reactjs Development Intern
# 422                         Node.js Development Intern
# 425              Front End Development Intern (Remote)
# 426                       Front End Development Intern
# 427           React Native Development Intern (Remote)
#
#                                                 Skills  \
# 22   Amazon Web Server (AWS) , Hadoop , MySQL , Python
# 24                  CSS , HTML , HTML&CSS , JavaScript
# 36           JavaScript , Node.js , React , TypeScript
# 37        Figma , GitHub , HTML , JavaScript , ReactJS
# ...

# %%
df['role'].value_counts()
# Out:
# role
# frontend        36
# backend         24
# data analyst     1
# Name: count, dtype: int64

# %%
df_final = df[['role', 'clean_Skills', 'clean_Description']].copy()
df_final
# Out:
#          role                                       clean_Skills  \
# 22    backend  amazon web server (aws) , hadoop , mysql , python
# 24   frontend                 css , html , html&css , javascript
# 36   frontend          javascript , node.js , react , typescript
# 37   frontend       figma , github , html , javascript , reactjs
# 38   frontend                                       react native
# ..        ...                                                ...
# 421  frontend       figma , html&css , tailwind css , typescript
# 422   backend  angular 7.0 , css , github , javascript , node...
# 425  frontend             css , html , mongodb , node.js , react
# 426  frontend  html&css , javascript , ui & ux design , wordp...
# 427  frontend  data analysis , data science , python , r prog...
#
#                                      clean_Description
# 22   mush should be eager to learn and develop skil...
# 24   as a front-end development intern at consumabl...
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, 22 to 427
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   role               61 non-null     object
#  1   clean_Skills       61 non-null     object
#  2   clean_Description  61 non-null     object
# dtypes: object(3)
# memory usage: 1.9+ KB

# %%
df_final.rename(columns={'clean_Skills': 'skills', 'clean_Description': 'description'}, inplace=True)
df_final
# Out:
#          role                                             skills  \
# 22    backend  amazon web server (aws) , hadoop , mysql , python
# 24   frontend                 css , html , html&css , javascript
# 36   frontend          javascript , node.js , react , typescript
# 37   frontend       figma , github , html , javascript , reactjs
# 38   frontend                                       react native
# ..        ...                                                ...
# 421  frontend       figma , html&css , tailwind css , typescript
# 422   backend  angular 7.0 , css , github , javascript , node...
# 425  frontend             css , html , mongodb , node.js , react
# 426  frontend  html&css , javascript , ui & ux design , wordp...
# 427  frontend  data analysis , data science , python , r prog...
#
#                                            description
# 22   mush should be eager to learn and develop skil...
# 24   as a front-end development intern at consumabl...
# ...
