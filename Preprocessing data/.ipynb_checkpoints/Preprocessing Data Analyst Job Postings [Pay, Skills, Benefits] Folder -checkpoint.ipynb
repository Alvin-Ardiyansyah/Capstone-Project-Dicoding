# %% [markdown]
# # Preprocessing Data Analyst Job Postings [Pay, Skills, Benefits] Folder

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import gdown

# %%
id = '1cHM6IvoayUw8wtIiquraGavdw3J6pqnM'
output = 'data_analyst_job_posting.csv'

if not os.path.exists(output):
    print("Download Dataset.....")
    gdown.download(f'https://drive.google.com/uc?id={id}',
                  output,
                  quiet=False # keterangan saat download
                  )
else:
    print("Dataset already exists")
# Out:
# Download Dataset.....
# Downloading...
# From (original): https://drive.google.com/uc?id=1cHM6IvoayUw8wtIiquraGavdw3J6pqnM
# From (redirected): https://drive.google.com/uc?id=1cHM6IvoayUw8wtIiquraGavdw3J6pqnM&confirm=t&uuid=84657651-cdd5-44a1-be03-e1280d76e074
# To: /home/alvin/Documents/Capstone-Project-Dicoding/Preprocessing data/data_analyst_job_posting.csv
# 100%|█████████████████████████████████████████| 290M/290M [11:51<00:00, 407kB/s]

# %%
df = pd.read_csv('./data_analyst_job_posting.csv')
df.head()
# Out:
#    Unnamed: 0  index                                             title  \
# 0           0      0                                      Data Analyst
# 1           1      1                                      Data Analyst
# 2           2      2                         Aeronautical Data Analyst
# 3           3      3  Data Analyst - Consumer Goods - Contract to Hire
# 4           4      4               Data Analyst | Workforce Management
#
#                  company_name            location           via  \
# 0                        Meta           Anywhere   via LinkedIn
# 1                         ATC    United States     via LinkedIn
# 2  Garmin International, Inc.       Olathe, KS       via Indeed
# 3                      Upwork           Anywhere     via Upwork
# 4                Krispy Kreme    United States     via LinkedIn
#
#                                          description  \
# 0  In the intersection of compliance and analytic...
# 1  Job Title: Entry Level Business Analyst / Prod...
# 2  Overview:\n\nWe are seeking a full-time...\nAe...
# 3  Enthusiastic Data Analyst for processing sales...
# 4  Overview of Position\n\nThis position will be ...
#
#                                           extensions  \
# 0  ['15 hours ago', '101K–143K a year', 'Work fro...
# 1  ['12 hours ago', 'Full-time', 'Health insurance']
# 2                      ['18 hours ago', 'Full-time']
# 3  ['12 hours ago', '15–25 an hour', 'Work from h...
# 4   ['7 hours ago', '90K–110K a year', 'Contractor']
#
#                                               job_id  \
# 0  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# 1  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# 2  eyJqb2JfdGl0bGUiOiJBZXJvbmF1dGljYWwgRGF0YSBBbm...
# 3  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QgLSBDb25zdW...
# 4  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QgfCBXb3JrZm...
#
#                                            thumbnail  ... commute_time  \
# 0  https://encrypted-tbn0.gstatic.com/images?q=tb...  ...          NaN
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...  ...          NaN
# 2                                                NaN  ...          NaN
# 3                                                NaN  ...          NaN
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...  ...          NaN
#
#   salary_pay salary_rate salary_avg salary_min salary_max salary_hourly  \
# 0  101K–143K      a year   122000.0   101000.0   143000.0           NaN
# 1        NaN         NaN        NaN        NaN        NaN           NaN
# 2        NaN         NaN        NaN        NaN        NaN           NaN
# 3      15–25     an hour       20.0       15.0       25.0          20.0
# 4   90K–110K      a year   100000.0    90000.0   110000.0           NaN
#
#    salary_yearly salary_standardized  \
# 0       122000.0            122000.0
# 1            NaN                 NaN
# 2            NaN                 NaN
# 3            NaN             41600.0
# 4       100000.0            100000.0
#
#                            description_tokens
# 0           ['tableau', 'r', 'python', 'sql']
# 1                                          []
# 2                                     ['sql']
# 3         ['powerpoint', 'excel', 'power_bi']
# 4  ['powerpoint', 'excel', 'outlook', 'word']
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61953 entries, 0 to 61952
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           61953 non-null  int64
#  1   index                61953 non-null  int64
#  2   title                61953 non-null  object
#  3   company_name         61953 non-null  object
#  4   location             61916 non-null  object
#  5   via                  61944 non-null  object
#  6   description          61953 non-null  object
#  7   extensions           61953 non-null  object
#  8   job_id               61953 non-null  object
#  9   thumbnail            38194 non-null  object
#  10  posted_at            61763 non-null  object
#  11  schedule_type        61707 non-null  object
#  12  work_from_home       27980 non-null  object
#  13  salary               10088 non-null  object
#  14  search_term          61953 non-null  object
#  15  date_time            61953 non-null  object
#  16  search_location      61953 non-null  object
#  17  commute_time         0 non-null      float64
#  18  salary_pay           10088 non-null  object
#  19  salary_rate          10088 non-null  object
#  20  salary_avg           10088 non-null  float64
#  21  salary_min           9512 non-null   float64
#  22  salary_max           9512 non-null   float64
#  23  salary_hourly        5900 non-null   float64
#  24  salary_yearly        4069 non-null   float64
#  25  salary_standardized  10088 non-null  float64
#  26  description_tokens   61953 non-null  object
# dtypes: float64(7), int64(2), object(18)
# memory usage: 12.8+ MB

# %%
df = df[['title', 'description', 'description_tokens']].copy()
df.head()
# Out:
#                                               title  \
# 0                                      Data Analyst
# 1                                      Data Analyst
# 2                         Aeronautical Data Analyst
# 3  Data Analyst - Consumer Goods - Contract to Hire
# 4               Data Analyst | Workforce Management
#
#                                          description  \
# 0  In the intersection of compliance and analytic...
# 1  Job Title: Entry Level Business Analyst / Prod...
# 2  Overview:\n\nWe are seeking a full-time...\nAe...
# 3  Enthusiastic Data Analyst for processing sales...
# 4  Overview of Position\n\nThis position will be ...
#
#                            description_tokens
# 0           ['tableau', 'r', 'python', 'sql']
# 1                                          []
# 2                                     ['sql']
# 3         ['powerpoint', 'excel', 'power_bi']
# 4  ['powerpoint', 'excel', 'outlook', 'word']

# %%
df['title'].unique()
# Out:
# array(['Data Analyst', 'Aeronautical Data Analyst',
#        'Data Analyst - Consumer Goods - Contract to Hire', ...,
#        'Data Analyst - Business Intelligence',
#        'COOP - Senior Data Analyst', 'Lead FP&A Analyst- Remote, US'],
#       dtype=object)

# %%
target_roles = ['data analyst', 'senior data analyst']

df = df[
    df['title']
    .str.strip()
    .str.lower()
    .isin(target_roles)
].copy()
df
# Out:
#                      title                                        description  \
# 0             Data Analyst  In the intersection of compliance and analytic...
# 1             Data Analyst  Job Title: Entry Level Business Analyst / Prod...
# 5             Data Analyst  Your Job\n\nFlint Hills Resources is seeking a...
# 7             Data Analyst  In order to be considered for this role, after...
# 9             Data Analyst  Job Summary: The Data Analyst oversees data pr...
# ...                    ...                                                ...
# 61883         Data Analyst  Job Description:\n\nWe are seeking a Data Anal...
# 61895  Senior Data Analyst  Job Description\n\nProvides programs to improv...
# 61922         Data Analyst  • InTulsa is partnering with Tulsa Remote to f...
# 61942         Data Analyst  What you will do:\n• Build reporting dashboard...
# 61943         Data Analyst  • InTulsa is partnering with Tulsa Remote to f...
#
#                                       description_tokens
# 0                      ['tableau', 'r', 'python', 'sql']
# 1                                                     []
# 5      ['power_bi', 'aws', 'excel', 'sql', 'mysql', '...
# 7      ['power_bi', 'tableau', 'jira', 'snowflake', '...
# 9                                        ['r', 'python']
# ...                                                  ...
# 61883                                                 []
# 61895  ['t-sql', 'power_bi', 'tableau', 'sharepoint',...
# 61922  ['bigquery', 'excel', 'javascript', 'power_bi'...
# 61942                                 ['tableau', 'sql']
# 61943  ['bigquery', 'excel', 'javascript', 'power_bi'...
#
# [8411 rows x 3 columns]

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6055 entries, 0 to 61942
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               6055 non-null   object
#  1   description         6055 non-null   object
#  2   description_tokens  6055 non-null   object
# dtypes: object(3)
# memory usage: 189.2+ KB

# %%
# Role Normalization

def map_role(title):
    title = title.lower()
    
    if 'data analyst' in title:
        return 'data analyst'
    elif 'frontend' in title or 'front end' in title or 'react' in title or 'front-end' in title:
        return 'frontend'
    elif "backend" in title or 'back end' in title or "node" in title or 'back-end' in title:
        return "backend"
    else:
        return None
df['role'] = df['title'].apply(map_role)
df = df[df['role'].notnull()].copy()
df
# Out:
#                      title                                        description  \
# 0             Data Analyst  In the intersection of compliance and analytic...
# 1             Data Analyst  Job Title: Entry Level Business Analyst / Prod...
# 5             Data Analyst  Your Job\n\nFlint Hills Resources is seeking a...
# 7             Data Analyst  In order to be considered for this role, after...
# 9             Data Analyst  Job Summary: The Data Analyst oversees data pr...
# ...                    ...                                                ...
# 61729         Data Analyst  Our client, a leader in the Data Industry, is ...
# 61822  Senior Data Analyst  Tickets For Less®, a leading live entertainmen...
# 61846         Data Analyst  Data Analyst Job Description Daniel's Restaura...
# 61895  Senior Data Analyst  Job Description\n\nProvides programs to improv...
# 61942         Data Analyst  What you will do:\n• Build reporting dashboard...
#
#                                       description_tokens          role
# 0                      ['tableau', 'r', 'python', 'sql']  data analyst
# 1                                                     []  data analyst
# 5      ['power_bi', 'aws', 'excel', 'sql', 'mysql', '...  data analyst
# 7      ['power_bi', 'tableau', 'jira', 'snowflake', '...  data analyst
# 9                                        ['r', 'python']  data analyst
# ...                                                  ...           ...
# 61729                                   ['excel', 'sql']  data analyst
# 61822  ['github', 'qlik', 'tableau', 'power_bi', 'bit...  data analyst
# 61846                                                 []  data analyst
# 61895  ['t-sql', 'power_bi', 'tableau', 'sharepoint',...  data analyst
# 61942                                 ['tableau', 'sql']  data analyst
#
# [6055 rows x 4 columns]

# %%
import re

def casefolding(text):
    return text.lower()

def cleaning(text):
    text = re.sub(r"http\S+", "", text)
    
    text = text.replace('\n', ' ')
    text = text.replace('*','')
    
    text = text.strip()
    
    text = re.sub(r'\s+', ' ', text)
    
    return text

for col in df.columns:
    df.loc[:, f"clean_{col}"] = df[col].apply(casefolding)
    df.loc[:, f"clean_{col}"] = df[f"clean_{col}"].apply(cleaning)
df
# Out:
#                      title                                        description  \
# 0             Data Analyst  In the intersection of compliance and analytic...
# 1             Data Analyst  Job Title: Entry Level Business Analyst / Prod...
# 5             Data Analyst  Your Job\n\nFlint Hills Resources is seeking a...
# 7             Data Analyst  In order to be considered for this role, after...
# 9             Data Analyst  Job Summary: The Data Analyst oversees data pr...
# ...                    ...                                                ...
# 61729         Data Analyst  Our client, a leader in the Data Industry, is ...
# 61822  Senior Data Analyst  Tickets For Less®, a leading live entertainmen...
# 61846         Data Analyst  Data Analyst Job Description Daniel's Restaura...
# 61895  Senior Data Analyst  Job Description\n\nProvides programs to improv...
# 61942         Data Analyst  What you will do:\n• Build reporting dashboard...
#
#                                       description_tokens          role  \
# 0                      ['tableau', 'r', 'python', 'sql']  data analyst
# 1                                                     []  data analyst
# 5      ['power_bi', 'aws', 'excel', 'sql', 'mysql', '...  data analyst
# 7      ['power_bi', 'tableau', 'jira', 'snowflake', '...  data analyst
# 9                                        ['r', 'python']  data analyst
# ...                                                  ...           ...
# 61729                                   ['excel', 'sql']  data analyst
# 61822  ['github', 'qlik', 'tableau', 'power_bi', 'bit...  data analyst
# 61846                                                 []  data analyst
# 61895  ['t-sql', 'power_bi', 'tableau', 'sharepoint',...  data analyst
# 61942                                 ['tableau', 'sql']  data analyst
#
#                clean_title                                  clean_description  \
# 0             data analyst  in the intersection of compliance and analytic...
# 1             data analyst  job title: entry level business analyst / prod...
# 5             data analyst  your job flint hills resources is seeking a da...
# 7             data analyst  in order to be considered for this role, after...
# 9             data analyst  job summary: the data analyst oversees data pr...
# ...                    ...                                                ...
# 61729         data analyst  our client, a leader in the data industry, is ...
# 61822  senior data analyst  tickets for less®, a leading live entertainmen...
# 61846         data analyst  data analyst job description daniel's restaura...
# 61895  senior data analyst  job description provides programs to improve o...
# 61942         data analyst  what you will do: • build reporting dashboards...
#
#                                 clean_description_tokens    clean_role
# 0                      ['tableau', 'r', 'python', 'sql']  data analyst
# 1                                                     []  data analyst
# 5      ['power_bi', 'aws', 'excel', 'sql', 'mysql', '...  data analyst
# 7      ['power_bi', 'tableau', 'jira', 'snowflake', '...  data analyst
# 9                                        ['r', 'python']  data analyst
# ...                                                  ...           ...
# 61729                                   ['excel', 'sql']  data analyst
# 61822  ['github', 'qlik', 'tableau', 'power_bi', 'bit...  data analyst
# 61846                                                 []  data analyst
# 61895  ['t-sql', 'power_bi', 'tableau', 'sharepoint',...  data analyst
# 61942                                 ['tableau', 'sql']  data analyst
#
# [6055 rows x 8 columns]

# %%
df['role'].value_counts()
# Out:
# role
# data analyst    6055
# Name: count, dtype: int64
