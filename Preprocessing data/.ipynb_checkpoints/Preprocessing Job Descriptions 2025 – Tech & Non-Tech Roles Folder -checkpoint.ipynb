# %% [markdown]
# # Preprocessing Job Descriptions 2025 – Tech & Non-Tech Roles Folder

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
id = '13iAabpkvzN9XgfUhD0m4ZIaIr2UUDPIh'
url = f'https://drive.google.com/uc?id={id}'
df = pd.read_csv(url)
df.head()
# Out:
#        JobID           Title ExperienceLevel YearsOfExperience  \
# 0  NET-F-001  .NET Developer         Fresher               0-1
# 1  NET-F-002  .NET Developer         Fresher               0-1
# 2  NET-F-003  .NET Developer         Fresher               0-1
# 3  NET-F-004  .NET Developer         Fresher               0-1
# 4  NET-F-005  .NET Developer         Fresher               0-1
#
#                                               Skills  \
# 0  C#; VB.NET basics; .NET Framework; .NET Core f...
# 1  C#; .NET Framework basics; ASP.NET; Razor; HTM...
# 2  C#; VB.NET basics; .NET Core; ASP.NET MVC; HTM...
# 3  C#; .NET Framework; ASP.NET basics; SQL Server...
# 4  C#; ASP.NET; MVC; Entity Framework basics; SQL...
#
#                                     Responsibilities  \
# 0  Assist in coding and debugging applications; L...
# 1  Write simple C# programs under guidance; Suppo...
# 2  Contribute to development of small modules; As...
# 3  Support in software design documentation; Assi...
# 4  Learn to design and build ASP.NET applications...
#
#                                             Keywords
# 0  .NET; C#; ASP.NET MVC; Entity Framework; SQL S...
# 1  .NET; C#; ASP.NET MVC; Entity Framework; SQL S...
# 2  .NET; C#; ASP.NET MVC; SQL Server; Entity Fram...
# 3    .NET; C#; SQL Server; Entity Framework; ASP.NET
# 4  .NET; C#; ASP.NET MVC; Entity Framework; SQL S...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   JobID              1068 non-null   object
#  1   Title              1067 non-null   object
#  2   ExperienceLevel    1068 non-null   object
#  3   YearsOfExperience  1068 non-null   object
#  4   Skills             1068 non-null   object
#  5   Responsibilities   1068 non-null   object
#  6   Keywords           1068 non-null   object
# dtypes: object(7)
# memory usage: 58.5+ KB

# %%
df.columns
# Out:
# Index(['JobID', 'Title', 'ExperienceLevel', 'YearsOfExperience', 'Skills',
#        'Responsibilities', 'Keywords'],
#       dtype='object')

# %%
df.drop(columns=['JobID', 'YearsOfExperience', 'Keywords'], inplace=True)
df.head()
# Out:
#             Title ExperienceLevel  \
# 0  .NET Developer         Fresher
# 1  .NET Developer         Fresher
# 2  .NET Developer         Fresher
# 3  .NET Developer         Fresher
# 4  .NET Developer         Fresher
#
#                                               Skills  \
# 0  C#; VB.NET basics; .NET Framework; .NET Core f...
# 1  C#; .NET Framework basics; ASP.NET; Razor; HTM...
# 2  C#; VB.NET basics; .NET Core; ASP.NET MVC; HTM...
# 3  C#; .NET Framework; ASP.NET basics; SQL Server...
# 4  C#; ASP.NET; MVC; Entity Framework basics; SQL...
#
#                                     Responsibilities
# 0  Assist in coding and debugging applications; L...
# 1  Write simple C# programs under guidance; Suppo...
# 2  Contribute to development of small modules; As...
# 3  Support in software design documentation; Assi...
# 4  Learn to design and build ASP.NET applications...

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1050 entries, 0 to 1067
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             1050 non-null   object
#  1   ExperienceLevel   1050 non-null   object
#  2   Skills            1050 non-null   object
#  3   Responsibilities  1050 non-null   object
# dtypes: object(4)
# memory usage: 41.0+ KB

# %%
# Role Normalization

def map_role(title):
    title = title.lower()
    
    if 'data analyst' in title:
        return 'data analyst'
    elif 'frontend' in title or 'front end' in title or 'react' in title or 'front-end' in title:
        return 'frontend'
    elif "backend" in title or 'back end' in title or "node" in title or 'back-end' in title:
        return "backend"
    else:
        return None
df['role'] = df['Title'].apply(map_role)
df = df[df['role'].notnull()].copy()
df
# Out:
#                                     Title   ExperienceLevel  \
# 100       Backend Developer - Entry Level           Fresher
# 101       Backend Developer - Entry Level           Fresher
# 102       Backend Developer - Entry Level           Fresher
# 103       Backend Developer - Entry Level           Fresher
# 104       Backend Developer - Entry Level           Fresher
# 105       Backend Developer - Entry Level           Fresher
# 106       Backend Developer - Entry Level           Fresher
# 107       Backend Developer - Entry Level           Fresher
# 108       Backend Developer - Entry Level           Fresher
# 109       Backend Developer - Entry Level           Fresher
# 110       Backend Developer - Experienced       Experienced
# 111       Backend Developer - Experienced       Experienced
# 112       Backend Developer - Experienced       Experienced
# 113       Backend Developer - Experienced       Experienced
# 114       Backend Developer - Experienced       Experienced
# 115       Backend Developer - Experienced       Experienced
# 116       Backend Developer - Experienced       Experienced
# 117       Backend Developer - Experienced       Experienced
# 118       Backend Developer - Experienced       Experienced
# 119       Backend Developer - Experienced       Experienced
# 300                Data Analyst - Fresher       Entry-Level
# 301                Data Analyst - Fresher       Entry-Level
# 302                Data Analyst - Fresher       Entry-Level
# 303                Data Analyst - Fresher       Entry-Level
# 304                Data Analyst - Fresher       Entry-Level
# 305                Data Analyst - Fresher       Entry-Level
# 306                Data Analyst - Fresher       Entry-Level
# 307                Data Analyst - Fresher       Entry-Level
# 308                Data Analyst - Fresher       Entry-Level
# 309            Data Analyst - Experienced      Senior-Level
# 310            Data Analyst - Experienced      Senior-Level
# 311            Data Analyst - Experienced      Senior-Level
# 312            Data Analyst - Experienced      Senior-Level
# 313            Data Analyst - Experienced      Senior-Level
# 314            Data Analyst - Experienced      Senior-Level
# 315            Data Analyst - Experienced      Senior-Level
# 316            Data Analyst - Experienced      Senior-Level
# 317            Data Analyst - Experienced      Senior-Level
# 318            Data Analyst - Experienced      Senior-Level
# 319            Data Analyst - Experienced      Senior-Level
# 342  Data Analyst / Data Scientist Intern           Fresher
# 427      Frontend Developer - Entry Level       Entry-Level
# 428      Frontend Developer - Entry Level       Entry-Level
# 429      Frontend Developer - Entry Level       Entry-Level
# 430      Frontend Developer - Entry Level       Entry-Level
# 431      Frontend Developer - Entry Level       Entry-Level
# 432      Frontend Developer - Entry Level       Entry-Level
# 433      Frontend Developer - Entry Level       Entry-Level
# 434      Frontend Developer - Entry Level       Entry-Level
# 435      Frontend Developer - Entry Level       Entry-Level
# 436      Frontend Developer - Entry Level       Entry-Level
# 437      Frontend Developer - Experienced  Mid-Senior Level
# 438      Frontend Developer - Experienced      Senior-Level
# 439      Frontend Developer - Experienced      Senior-Level
# 440      Frontend Developer - Experienced      Senior-Level
# 441      Frontend Developer - Experienced      Senior-Level
# 442      Frontend Developer - Experienced      Senior-Level
# 443      Frontend Developer - Experienced      Senior-Level
# 444      Frontend Developer - Experienced      Senior-Level
#
#                                                 Skills  \
# 100  Node.js; Python; Java; Express.js; Flask; Djan...
# 101  Node.js; Python; Java; Express.js; Flask; Djan...
# 102  Node.js; Python; Express.js; Flask; Django; My...
# 103  Node.js; Python; Express.js; Flask; Django; My...
# 104  Node.js; Python; Java; Express.js; Flask; Djan...
# 105  Node.js; Python; Java; Express.js; Flask; Djan...
# 106  Node.js; Python; Express.js; Django; Flask; My...
# 107  Node.js; Python; Java; Express.js; Django; Fla...
# 108  Node.js; Python; Express.js; Flask; Django; My...
# 109  Node.js; Python; Java; Express.js; Django; Fla...
# 110  Node.js; Python; Java; Go; Express.js; Django;...
# 111  Java; Go; Node.js; Spring Boot; Express.js; Po...
# 112  Python; Node.js; Django; Flask; Express.js; Po...
# 113  Node.js; Python; Java; Express.js; Django; Fla...
# 114  Python; Node.js; Go; Django; Flask; Express.js...
# 115  Node.js; Java; Python; Express.js; Spring Boot...
# 116  Python; Node.js; Java; Django; Flask; Express....
# 117  Java; Go; Python; Spring Boot; Express.js; Dja...
# 118  Node.js; Python; Java; Express.js; Django; Spr...
# 119  Node.js; Python; Go; Express.js; Django; Flask...
# 300  SQL; Python; R; SAS; Tableau; Power BI; Matplo...
# 301  SQL; Python; R; Tableau; Power BI; Excel chart...
# 302  SQL; Python; R; SAS; Tableau; Power BI; Matplo...
# 303  SQL; Python; R; Tableau; Power BI; Excel; Pand...
# 304  SQL; Python; R; SAS; Tableau; Power BI; Matplo...
# 305  SQL; Python; R; Tableau; Power BI; Matplotlib;...
# 306  SQL; Python; R; Tableau; Power BI; Excel chart...
# 307  SQL; Python; R; Tableau; Power BI; Excel chart...
# 308  SQL; Python; R; SAS; Tableau; Power BI; Matplo...
# 309  Predictive modeling; Machine learning algorith...
# 310  Predictive modeling; Machine learning; Time-se...
# 311  Predictive modeling; Advanced analytics; Machi...
# 312  Advanced SQL; Python; R; Predictive modeling; ...
# 313  Predictive modeling; Machine learning; Advance...
# 314  Advanced SQL; Python; R; Predictive modeling; ...
# 315  Advanced SQL; Python; R; Predictive modeling; ...
# 316  Advanced SQL; Python; R; SAS; Predictive model...
# 317  Advanced SQL; Python; R; Predictive modeling; ...
# 318  Advanced SQL; Python; R; Predictive modeling; ...
# 319  Advanced SQL; Python; R; Predictive modeling; ...
# 342  Python; R; SQL; Pandas; NumPy; Matplotlib; Sea...
# 427  HTML; CSS; JavaScript; React basics; Angular b...
# 428  HTML5; CSS3; JavaScript (ES6+); React; Vue.js;...
# 429  HTML; CSS; JavaScript; React basics; Angular b...
# 430  HTML5; CSS3; JavaScript (ES6+); React basics; ...
# 431  HTML; CSS; JavaScript; React basics; Angular b...
# 432  HTML; CSS; JavaScript; React basics; Angular b...
# 433  HTML; CSS; JavaScript; React basics; Vue.js ba...
# 434  HTML; CSS; JavaScript; React basics; Angular b...
# 435  HTML; CSS; JavaScript; React basics; Vue.js ba...
# 436  HTML; CSS; JavaScript; React basics; Angular b...
# 437  HTML5; CSS3; JavaScript (ES6+); React/Redux; A...
# 438  React/Redux; Angular; Vue.js; HTML; CSS; JavaS...
# 439  Advanced React; Angular; Vue.js; HTML; CSS; Ja...
# 440  React/Redux; Angular; Vue.js; HTML; CSS; JavaS...
# 441  Advanced React (Hooks, Redux); Angular; Vue.js...
# 442  React/Redux; Angular; Vue.js; HTML; CSS; JavaS...
# 443  React/Redux; Angular; Vue.js; HTML; CSS; JavaS...
# 444  React/Redux; Angular; Vue.js; HTML; CSS; JavaS...
#
#                                       Responsibilities          role
# 100  Assist in building server-side applications; D...       backend
# 101  Implement scalable backend services; Develop A...       backend
# 102  Develop and maintain backend APIs; Optimize da...       backend
# 103  Server-side development for web and mobile app...       backend
# 104  Design and develop backend services; Write eff...       backend
# 105  Develop backend modules; Assist in API develop...       backend
# 106  Assist in developing backend services for web ...       backend
# 107  Server-side components for web and mobile apps...       backend
# 108  Assist in backend development of scalable APIs...       backend
# 109  Assist in backend development; Develop APIs; M...       backend
# 110  Design, develop, and maintain backend services...       backend
# 111  Lead backend development for fintech applicati...       backend
# 112  Architect backend systems for healthcare appli...       backend
# 113  Lead backend engineering for e-commerce platfo...       backend
# 114  Design backend services for AI-powered applica...       backend
# 115  Lead backend infrastructure for logistics plat...       backend
# 116  Architect backend solutions for SaaS applicati...       backend
# 117  Develop backend systems for fintech and bankin...       backend
# 118  Lead backend development for large-scale socia...       backend
# 119  Architect backend solutions for media streamin...       backend
# 300  Assist in analyzing datasets; Create dashboard...  data analyst
# 301  Perform data extraction and cleaning; Create v...  data analyst
# 302  Assist with data cleaning and exploratory data...  data analyst
# 303  Support data extraction and cleaning; Generate...  data analyst
# 304  Assist in cleaning datasets; Build simple dash...  data analyst
# 305  Support teams in analyzing datasets; Perform d...  data analyst
# 306  Assist in ETL processes; Perform data cleaning...  data analyst
# 307  Perform data cleaning; Generate dashboards; As...  data analyst
# 308  Assist teams with SQL queries; Process data us...  data analyst
# 309  Lead analytics projects; Develop predictive mo...  data analyst
# 310  Design and implement advanced analytics soluti...  data analyst
# 311  Lead business intelligence projects; Develop p...  data analyst
# 312  Develop advanced dashboards; Optimize SQL quer...  data analyst
# 313  Lead analytics and BI projects; Manage data pi...  data analyst
# 314  Design and implement analytics dashboards; Opt...  data analyst
# 315  Lead analytics initiatives; Design predictive ...  data analyst
# 316  Manage large-scale analytics projects; Impleme...  data analyst
# 317  Design and implement analytics dashboards; Opt...  data analyst
# 318  Lead analytics and BI projects; Manage data pi...  data analyst
# 319  Manage large-scale analytics projects; Impleme...  data analyst
# 342  Assist in data collection, cleaning, and analy...  data analyst
# 427  Build responsive and interactive web pages; Im...      frontend
# 428  Develop web interfaces for internal tools; Imp...      frontend
# 429  Work on small projects and personal applicatio...      frontend
# 430  Assist in designing and coding responsive web ...      frontend
# 431  Create and maintain frontend components; Parti...      frontend
# 432  Develop interactive UI pages for internal dash...      frontend
# 433  Assist in implementing UI features for web app...      frontend
# 434  Build responsive web pages; Assist in integrat...      frontend
# 435  Assist in creating web interfaces and componen...      frontend
# 436  Work on academic and personal projects; Develo...      frontend
# 437  Design and develop advanced frontend applicati...      frontend
# 438  Lead frontend development for scalable applica...      frontend
# 439  Architect and implement frontend solutions; Le...      frontend
# 440  Lead frontend initiatives for e-commerce platf...      frontend
# 441  Architect scalable web dashboards and SPAs; Op...      frontend
# 442  Lead frontend development for SaaS products; I...      frontend
# 443  Build and optimize frontend for media streamin...      frontend
# 444  Lead frontend for AI-powered dashboards; Build...      frontend

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 100 to 444
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             59 non-null     object
#  1   ExperienceLevel   59 non-null     object
#  2   Skills            59 non-null     object
#  3   Responsibilities  59 non-null     object
#  4   role              59 non-null     object
# dtypes: object(5)
# memory usage: 2.8+ KB

# %%
import re

def casefolding(text):
    return text.lower()

def cleaning(text):
    text = re.sub(r"http\S+", "", text)
    
    text = text.replace('\n', ' ')
    text = text.replace('*','')
    text = text.replace(';',',')
    
    text = text.strip()
    
    text = re.sub(r'\s+', ' ', text)
    
    return text

for col in df.columns:
    df.loc[:, f"clean_{col}"] = df[col].apply(casefolding)
    df.loc[:, f"clean_{col}"] = df[f"clean_{col}"].apply(cleaning)
df
# Out:
#                                     Title   ExperienceLevel  \
# 100       Backend Developer - Entry Level           Fresher
# 101       Backend Developer - Entry Level           Fresher
# 102       Backend Developer - Entry Level           Fresher
# 103       Backend Developer - Entry Level           Fresher
# 104       Backend Developer - Entry Level           Fresher
# 105       Backend Developer - Entry Level           Fresher
# 106       Backend Developer - Entry Level           Fresher
# 107       Backend Developer - Entry Level           Fresher
# 108       Backend Developer - Entry Level           Fresher
# 109       Backend Developer - Entry Level           Fresher
# 110       Backend Developer - Experienced       Experienced
# 111       Backend Developer - Experienced       Experienced
# 112       Backend Developer - Experienced       Experienced
# 113       Backend Developer - Experienced       Experienced
# 114       Backend Developer - Experienced       Experienced
# 115       Backend Developer - Experienced       Experienced
# 116       Backend Developer - Experienced       Experienced
# 117       Backend Developer - Experienced       Experienced
# 118       Backend Developer - Experienced       Experienced
# 119       Backend Developer - Experienced       Experienced
# 300                Data Analyst - Fresher       Entry-Level
# 301                Data Analyst - Fresher       Entry-Level
# 302                Data Analyst - Fresher       Entry-Level
# 303                Data Analyst - Fresher       Entry-Level
# 304                Data Analyst - Fresher       Entry-Level
# 305                Data Analyst - Fresher       Entry-Level
# 306                Data Analyst - Fresher       Entry-Level
# 307                Data Analyst - Fresher       Entry-Level
# 308                Data Analyst - Fresher       Entry-Level
# 309            Data Analyst - Experienced      Senior-Level
# 310            Data Analyst - Experienced      Senior-Level
# 311            Data Analyst - Experienced      Senior-Level
# 312            Data Analyst - Experienced      Senior-Level
# 313            Data Analyst - Experienced      Senior-Level
# 314            Data Analyst - Experienced      Senior-Level
# 315            Data Analyst - Experienced      Senior-Level
# 316            Data Analyst - Experienced      Senior-Level
# 317            Data Analyst - Experienced      Senior-Level
# 318            Data Analyst - Experienced      Senior-Level
# 319            Data Analyst - Experienced      Senior-Level
# 342  Data Analyst / Data Scientist Intern           Fresher
# 427      Frontend Developer - Entry Level       Entry-Level
# 428      Frontend Developer - Entry Level       Entry-Level
# 429      Frontend Developer - Entry Level       Entry-Level
# 430      Frontend Developer - Entry Level       Entry-Level
# 431      Frontend Developer - Entry Level       Entry-Level
# 432      Frontend Developer - Entry Level       Entry-Level
# 433      Frontend Developer - Entry Level       Entry-Level
# 434      Frontend Developer - Entry Level       Entry-Level
# 435      Frontend Developer - Entry Level       Entry-Level
# 436      Frontend Developer - Entry Level       Entry-Level
# 437      Frontend Developer - Experienced  Mid-Senior Level
# 438      Frontend Developer - Experienced      Senior-Level
# 439      Frontend Developer - Experienced      Senior-Level
# 440      Frontend Developer - Experienced      Senior-Level
# 441      Frontend Developer - Experienced      Senior-Level
# 442      Frontend Developer - Experienced      Senior-Level
# 443      Frontend Developer - Experienced      Senior-Level
# 444      Frontend Developer - Experienced      Senior-Level
#
#                                                 Skills  \
# 100  Node.js; Python; Java; Express.js; Flask; Djan...
# 101  Node.js; Python; Java; Express.js; Flask; Djan...
# 102  Node.js; Python; Express.js; Flask; Django; My...
# 103  Node.js; Python; Express.js; Flask; Django; My...
# 104  Node.js; Python; Java; Express.js; Flask; Djan...
# 105  Node.js; Python; Java; Express.js; Flask; Djan...
# 106  Node.js; Python; Express.js; Django; Flask; My...
# 107  Node.js; Python; Java; Express.js; Django; Fla...
# 108  Node.js; Python; Express.js; Flask; Django; My...
# 109  Node.js; Python; Java; Express.js; Django; Fla...
# 110  Node.js; Python; Java; Go; Express.js; Django;...
# 111  Java; Go; Node.js; Spring Boot; Express.js; Po...
# 112  Python; Node.js; Django; Flask; Express.js; Po...
# 113  Node.js; Python; Java; Express.js; Django; Fla...
# 114  Python; Node.js; Go; Django; Flask; Express.js...
# 115  Node.js; Java; Python; Express.js; Spring Boot...
# 116  Python; Node.js; Java; Django; Flask; Express....
# 117  Java; Go; Python; Spring Boot; Express.js; Dja...
# 118  Node.js; Python; Java; Express.js; Django; Spr...
# 119  Node.js; Python; Go; Express.js; Django; Flask...
# 300  SQL; Python; R; SAS; Tableau; Power BI; Matplo...
# 301  SQL; Python; R; Tableau; Power BI; Excel chart...
# 302  SQL; Python; R; SAS; Tableau; Power BI; Matplo...
# 303  SQL; Python; R; Tableau; Power BI; Excel; Pand...
# 304  SQL; Python; R; SAS; Tableau; Power BI; Matplo...
# 305  SQL; Python; R; Tableau; Power BI; Matplotlib;...
# 306  SQL; Python; R; Tableau; Power BI; Excel chart...
# 307  SQL; Python; R; Tableau; Power BI; Excel chart...
# 308  SQL; Python; R; SAS; Tableau; Power BI; Matplo...
# 309  Predictive modeling; Machine learning algorith...
# 310  Predictive modeling; Machine learning; Time-se...
# 311  Predictive modeling; Advanced analytics; Machi...
# 312  Advanced SQL; Python; R; Predictive modeling; ...
# 313  Predictive modeling; Machine learning; Advance...
# 314  Advanced SQL; Python; R; Predictive modeling; ...
# 315  Advanced SQL; Python; R; Predictive modeling; ...
# 316  Advanced SQL; Python; R; SAS; Predictive model...
# 317  Advanced SQL; Python; R; Predictive modeling; ...
# 318  Advanced SQL; Python; R; Predictive modeling; ...
# 319  Advanced SQL; Python; R; Predictive modeling; ...
# 342  Python; R; SQL; Pandas; NumPy; Matplotlib; Sea...
# 427  HTML; CSS; JavaScript; React basics; Angular b...
# 428  HTML5; CSS3; JavaScript (ES6+); React; Vue.js;...
# 429  HTML; CSS; JavaScript; React basics; Angular b...
# 430  HTML5; CSS3; JavaScript (ES6+); React basics; ...
# 431  HTML; CSS; JavaScript; React basics; Angular b...
# 432  HTML; CSS; JavaScript; React basics; Angular b...
# 433  HTML; CSS; JavaScript; React basics; Vue.js ba...
# 434  HTML; CSS; JavaScript; React basics; Angular b...
# 435  HTML; CSS; JavaScript; React basics; Vue.js ba...
# 436  HTML; CSS; JavaScript; React basics; Angular b...
# 437  HTML5; CSS3; JavaScript (ES6+); React/Redux; A...
# 438  React/Redux; Angular; Vue.js; HTML; CSS; JavaS...
# 439  Advanced React; Angular; Vue.js; HTML; CSS; Ja...
# 440  React/Redux; Angular; Vue.js; HTML; CSS; JavaS...
# 441  Advanced React (Hooks, Redux); Angular; Vue.js...
# 442  React/Redux; Angular; Vue.js; HTML; CSS; JavaS...
# 443  React/Redux; Angular; Vue.js; HTML; CSS; JavaS...
# 444  React/Redux; Angular; Vue.js; HTML; CSS; JavaS...
#
#                                       Responsibilities          role  \
# 100  Assist in building server-side applications; D...       backend
# 101  Implement scalable backend services; Develop A...       backend
# 102  Develop and maintain backend APIs; Optimize da...       backend
# 103  Server-side development for web and mobile app...       backend
# 104  Design and develop backend services; Write eff...       backend
# 105  Develop backend modules; Assist in API develop...       backend
# 106  Assist in developing backend services for web ...       backend
# 107  Server-side components for web and mobile apps...       backend
# 108  Assist in backend development of scalable APIs...       backend
# 109  Assist in backend development; Develop APIs; M...       backend
# 110  Design, develop, and maintain backend services...       backend
# 111  Lead backend development for fintech applicati...       backend
# 112  Architect backend systems for healthcare appli...       backend
# 113  Lead backend engineering for e-commerce platfo...       backend
# 114  Design backend services for AI-powered applica...       backend
# 115  Lead backend infrastructure for logistics plat...       backend
# 116  Architect backend solutions for SaaS applicati...       backend
# 117  Develop backend systems for fintech and bankin...       backend
# 118  Lead backend development for large-scale socia...       backend
# 119  Architect backend solutions for media streamin...       backend
# 300  Assist in analyzing datasets; Create dashboard...  data analyst
# 301  Perform data extraction and cleaning; Create v...  data analyst
# 302  Assist with data cleaning and exploratory data...  data analyst
# 303  Support data extraction and cleaning; Generate...  data analyst
# 304  Assist in cleaning datasets; Build simple dash...  data analyst
# 305  Support teams in analyzing datasets; Perform d...  data analyst
# 306  Assist in ETL processes; Perform data cleaning...  data analyst
# 307  Perform data cleaning; Generate dashboards; As...  data analyst
# 308  Assist teams with SQL queries; Process data us...  data analyst
# 309  Lead analytics projects; Develop predictive mo...  data analyst
# 310  Design and implement advanced analytics soluti...  data analyst
# 311  Lead business intelligence projects; Develop p...  data analyst
# 312  Develop advanced dashboards; Optimize SQL quer...  data analyst
# 313  Lead analytics and BI projects; Manage data pi...  data analyst
# 314  Design and implement analytics dashboards; Opt...  data analyst
# 315  Lead analytics initiatives; Design predictive ...  data analyst
# 316  Manage large-scale analytics projects; Impleme...  data analyst
# 317  Design and implement analytics dashboards; Opt...  data analyst
# 318  Lead analytics and BI projects; Manage data pi...  data analyst
# 319  Manage large-scale analytics projects; Impleme...  data analyst
# 342  Assist in data collection, cleaning, and analy...  data analyst
# 427  Build responsive and interactive web pages; Im...      frontend
# 428  Develop web interfaces for internal tools; Imp...      frontend
# 429  Work on small projects and personal applicatio...      frontend
# 430  Assist in designing and coding responsive web ...      frontend
# 431  Create and maintain frontend components; Parti...      frontend
# 432  Develop interactive UI pages for internal dash...      frontend
# 433  Assist in implementing UI features for web app...      frontend
# 434  Build responsive web pages; Assist in integrat...      frontend
# 435  Assist in creating web interfaces and componen...      frontend
# 436  Work on academic and personal projects; Develo...      frontend
# 437  Design and develop advanced frontend applicati...      frontend
# 438  Lead frontend development for scalable applica...      frontend
# 439  Architect and implement frontend solutions; Le...      frontend
# 440  Lead frontend initiatives for e-commerce platf...      frontend
# 441  Architect scalable web dashboards and SPAs; Op...      frontend
# 442  Lead frontend development for SaaS products; I...      frontend
# 443  Build and optimize frontend for media streamin...      frontend
# 444  Lead frontend for AI-powered dashboards; Build...      frontend
#
#                               clean_Title clean_ExperienceLevel  \
# 100       backend developer - entry level               fresher
# 101       backend developer - entry level               fresher
# 102       backend developer - entry level               fresher
# 103       backend developer - entry level               fresher
# 104       backend developer - entry level               fresher
# 105       backend developer - entry level               fresher
# 106       backend developer - entry level               fresher
# 107       backend developer - entry level               fresher
# 108       backend developer - entry level               fresher
# 109       backend developer - entry level               fresher
# 110       backend developer - experienced           experienced
# 111       backend developer - experienced           experienced
# 112       backend developer - experienced           experienced
# 113       backend developer - experienced           experienced
# 114       backend developer - experienced           experienced
# 115       backend developer - experienced           experienced
# 116       backend developer - experienced           experienced
# 117       backend developer - experienced           experienced
# 118       backend developer - experienced           experienced
# 119       backend developer - experienced           experienced
# 300                data analyst - fresher           entry-level
# 301                data analyst - fresher           entry-level
# 302                data analyst - fresher           entry-level
# 303                data analyst - fresher           entry-level
# 304                data analyst - fresher           entry-level
# 305                data analyst - fresher           entry-level
# 306                data analyst - fresher           entry-level
# 307                data analyst - fresher           entry-level
# 308                data analyst - fresher           entry-level
# 309            data analyst - experienced          senior-level
# 310            data analyst - experienced          senior-level
# 311            data analyst - experienced          senior-level
# 312            data analyst - experienced          senior-level
# 313            data analyst - experienced          senior-level
# 314            data analyst - experienced          senior-level
# 315            data analyst - experienced          senior-level
# 316            data analyst - experienced          senior-level
# 317            data analyst - experienced          senior-level
# 318            data analyst - experienced          senior-level
# 319            data analyst - experienced          senior-level
# 342  data analyst / data scientist intern               fresher
# 427      frontend developer - entry level           entry-level
# 428      frontend developer - entry level           entry-level
# 429      frontend developer - entry level           entry-level
# 430      frontend developer - entry level           entry-level
# 431      frontend developer - entry level           entry-level
# 432      frontend developer - entry level           entry-level
# 433      frontend developer - entry level           entry-level
# 434      frontend developer - entry level           entry-level
# 435      frontend developer - entry level           entry-level
# 436      frontend developer - entry level           entry-level
# 437      frontend developer - experienced      mid-senior level
# 438      frontend developer - experienced          senior-level
# 439      frontend developer - experienced          senior-level
# 440      frontend developer - experienced          senior-level
# 441      frontend developer - experienced          senior-level
# 442      frontend developer - experienced          senior-level
# 443      frontend developer - experienced          senior-level
# 444      frontend developer - experienced          senior-level
#
#                                           clean_Skills  \
# 100  node.js, python, java, express.js, flask, djan...
# 101  node.js, python, java, express.js, flask, djan...
# 102  node.js, python, express.js, flask, django, my...
# 103  node.js, python, express.js, flask, django, my...
# 104  node.js, python, java, express.js, flask, djan...
# 105  node.js, python, java, express.js, flask, djan...
# 106  node.js, python, express.js, django, flask, my...
# 107  node.js, python, java, express.js, django, fla...
# 108  node.js, python, express.js, flask, django, my...
# 109  node.js, python, java, express.js, django, fla...
# 110  node.js, python, java, go, express.js, django,...
# 111  java, go, node.js, spring boot, express.js, po...
# 112  python, node.js, django, flask, express.js, po...
# 113  node.js, python, java, express.js, django, fla...
# 114  python, node.js, go, django, flask, express.js...
# 115  node.js, java, python, express.js, spring boot...
# 116  python, node.js, java, django, flask, express....
# 117  java, go, python, spring boot, express.js, dja...
# 118  node.js, python, java, express.js, django, spr...
# 119  node.js, python, go, express.js, django, flask...
# 300  sql, python, r, sas, tableau, power bi, matplo...
# 301  sql, python, r, tableau, power bi, excel chart...
# 302  sql, python, r, sas, tableau, power bi, matplo...
# 303  sql, python, r, tableau, power bi, excel, pand...
# 304  sql, python, r, sas, tableau, power bi, matplo...
# 305  sql, python, r, tableau, power bi, matplotlib,...
# 306  sql, python, r, tableau, power bi, excel chart...
# 307  sql, python, r, tableau, power bi, excel chart...
# 308  sql, python, r, sas, tableau, power bi, matplo...
# 309  predictive modeling, machine learning algorith...
# 310  predictive modeling, machine learning, time-se...
# 311  predictive modeling, advanced analytics, machi...
# 312  advanced sql, python, r, predictive modeling, ...
# 313  predictive modeling, machine learning, advance...
# 314  advanced sql, python, r, predictive modeling, ...
# 315  advanced sql, python, r, predictive modeling, ...
# 316  advanced sql, python, r, sas, predictive model...
# 317  advanced sql, python, r, predictive modeling, ...
# 318  advanced sql, python, r, predictive modeling, ...
# 319  advanced sql, python, r, predictive modeling, ...
# 342  python, r, sql, pandas, numpy, matplotlib, sea...
# 427  html, css, javascript, react basics, angular b...
# 428  html5, css3, javascript (es6+), react, vue.js,...
# 429  html, css, javascript, react basics, angular b...
# 430  html5, css3, javascript (es6+), react basics, ...
# 431  html, css, javascript, react basics, angular b...
# 432  html, css, javascript, react basics, angular b...
# 433  html, css, javascript, react basics, vue.js ba...
# 434  html, css, javascript, react basics, angular b...
# 435  html, css, javascript, react basics, vue.js ba...
# 436  html, css, javascript, react basics, angular b...
# 437  html5, css3, javascript (es6+), react/redux, a...
# 438  react/redux, angular, vue.js, html, css, javas...
# 439  advanced react, angular, vue.js, html, css, ja...
# 440  react/redux, angular, vue.js, html, css, javas...
# 441  advanced react (hooks, redux), angular, vue.js...
# 442  react/redux, angular, vue.js, html, css, javas...
# 443  react/redux, angular, vue.js, html, css, javas...
# 444  react/redux, angular, vue.js, html, css, javas...
#
#                                 clean_Responsibilities    clean_role
# 100  assist in building server-side applications, d...       backend
# 101  implement scalable backend services, develop a...       backend
# 102  develop and maintain backend apis, optimize da...       backend
# 103  server-side development for web and mobile app...       backend
# 104  design and develop backend services, write eff...       backend
# 105  develop backend modules, assist in api develop...       backend
# 106  assist in developing backend services for web ...       backend
# 107  server-side components for web and mobile apps...       backend
# 108  assist in backend development of scalable apis...       backend
# 109  assist in backend development, develop apis, m...       backend
# 110  design, develop, and maintain backend services...       backend
# 111  lead backend development for fintech applicati...       backend
# 112  architect backend systems for healthcare appli...       backend
# 113  lead backend engineering for e-commerce platfo...       backend
# 114  design backend services for ai-powered applica...       backend
# 115  lead backend infrastructure for logistics plat...       backend
# 116  architect backend solutions for saas applicati...       backend
# 117  develop backend systems for fintech and bankin...       backend
# 118  lead backend development for large-scale socia...       backend
# 119  architect backend solutions for media streamin...       backend
# 300  assist in analyzing datasets, create dashboard...  data analyst
# 301  perform data extraction and cleaning, create v...  data analyst
# 302  assist with data cleaning and exploratory data...  data analyst
# 303  support data extraction and cleaning, generate...  data analyst
# 304  assist in cleaning datasets, build simple dash...  data analyst
# 305  support teams in analyzing datasets, perform d...  data analyst
# 306  assist in etl processes, perform data cleaning...  data analyst
# 307  perform data cleaning, generate dashboards, as...  data analyst
# 308  assist teams with sql queries, process data us...  data analyst
# 309  lead analytics projects, develop predictive mo...  data analyst
# 310  design and implement advanced analytics soluti...  data analyst
# 311  lead business intelligence projects, develop p...  data analyst
# 312  develop advanced dashboards, optimize sql quer...  data analyst
# 313  lead analytics and bi projects, manage data pi...  data analyst
# 314  design and implement analytics dashboards, opt...  data analyst
# 315  lead analytics initiatives, design predictive ...  data analyst
# 316  manage large-scale analytics projects, impleme...  data analyst
# 317  design and implement analytics dashboards, opt...  data analyst
# 318  lead analytics and bi projects, manage data pi...  data analyst
# 319  manage large-scale analytics projects, impleme...  data analyst
# 342  assist in data collection, cleaning, and analy...  data analyst
# 427  build responsive and interactive web pages, im...      frontend
# 428  develop web interfaces for internal tools, imp...      frontend
# 429  work on small projects and personal applicatio...      frontend
# 430  assist in designing and coding responsive web ...      frontend
# 431  create and maintain frontend components, parti...      frontend
# 432  develop interactive ui pages for internal dash...      frontend
# 433  assist in implementing ui features for web app...      frontend
# 434  build responsive web pages, assist in integrat...      frontend
# 435  assist in creating web interfaces and componen...      frontend
# 436  work on academic and personal projects, develo...      frontend
# 437  design and develop advanced frontend applicati...      frontend
# 438  lead frontend development for scalable applica...      frontend
# 439  architect and implement frontend solutions, le...      frontend
# 440  lead frontend initiatives for e-commerce platf...      frontend
# 441  architect scalable web dashboards and spas, op...      frontend
# 442  lead frontend development for saas products, i...      frontend
# 443  build and optimize frontend for media streamin...      frontend
# 444  lead frontend for ai-powered dashboards, build...      frontend

# %%
df['role'].value_counts()
# Out:
# role
# data analyst    21
# backend         20
# frontend        18
# Name: count, dtype: int64

# %%
df_final = df[['role', 'clean_Skills', 'clean_Responsibilities']].copy()
df_final
# Out:
#              role                                       clean_Skills  \
# 100       backend  node.js, python, java, express.js, flask, djan...
# 101       backend  node.js, python, java, express.js, flask, djan...
# 102       backend  node.js, python, express.js, flask, django, my...
# 103       backend  node.js, python, express.js, flask, django, my...
# 104       backend  node.js, python, java, express.js, flask, djan...
# 105       backend  node.js, python, java, express.js, flask, djan...
# 106       backend  node.js, python, express.js, django, flask, my...
# 107       backend  node.js, python, java, express.js, django, fla...
# 108       backend  node.js, python, express.js, flask, django, my...
# 109       backend  node.js, python, java, express.js, django, fla...
# 110       backend  node.js, python, java, go, express.js, django,...
# 111       backend  java, go, node.js, spring boot, express.js, po...
# 112       backend  python, node.js, django, flask, express.js, po...
# 113       backend  node.js, python, java, express.js, django, fla...
# 114       backend  python, node.js, go, django, flask, express.js...
# 115       backend  node.js, java, python, express.js, spring boot...
# 116       backend  python, node.js, java, django, flask, express....
# 117       backend  java, go, python, spring boot, express.js, dja...
# 118       backend  node.js, python, java, express.js, django, spr...
# 119       backend  node.js, python, go, express.js, django, flask...
# 300  data analyst  sql, python, r, sas, tableau, power bi, matplo...
# 301  data analyst  sql, python, r, tableau, power bi, excel chart...
# 302  data analyst  sql, python, r, sas, tableau, power bi, matplo...
# 303  data analyst  sql, python, r, tableau, power bi, excel, pand...
# 304  data analyst  sql, python, r, sas, tableau, power bi, matplo...
# 305  data analyst  sql, python, r, tableau, power bi, matplotlib,...
# 306  data analyst  sql, python, r, tableau, power bi, excel chart...
# 307  data analyst  sql, python, r, tableau, power bi, excel chart...
# 308  data analyst  sql, python, r, sas, tableau, power bi, matplo...
# 309  data analyst  predictive modeling, machine learning algorith...
# 310  data analyst  predictive modeling, machine learning, time-se...
# 311  data analyst  predictive modeling, advanced analytics, machi...
# 312  data analyst  advanced sql, python, r, predictive modeling, ...
# 313  data analyst  predictive modeling, machine learning, advance...
# 314  data analyst  advanced sql, python, r, predictive modeling, ...
# 315  data analyst  advanced sql, python, r, predictive modeling, ...
# 316  data analyst  advanced sql, python, r, sas, predictive model...
# 317  data analyst  advanced sql, python, r, predictive modeling, ...
# 318  data analyst  advanced sql, python, r, predictive modeling, ...
# 319  data analyst  advanced sql, python, r, predictive modeling, ...
# 342  data analyst  python, r, sql, pandas, numpy, matplotlib, sea...
# 427      frontend  html, css, javascript, react basics, angular b...
# 428      frontend  html5, css3, javascript (es6+), react, vue.js,...
# 429      frontend  html, css, javascript, react basics, angular b...
# 430      frontend  html5, css3, javascript (es6+), react basics, ...
# 431      frontend  html, css, javascript, react basics, angular b...
# 432      frontend  html, css, javascript, react basics, angular b...
# 433      frontend  html, css, javascript, react basics, vue.js ba...
# 434      frontend  html, css, javascript, react basics, angular b...
# 435      frontend  html, css, javascript, react basics, vue.js ba...
# 436      frontend  html, css, javascript, react basics, angular b...
# 437      frontend  html5, css3, javascript (es6+), react/redux, a...
# 438      frontend  react/redux, angular, vue.js, html, css, javas...
# 439      frontend  advanced react, angular, vue.js, html, css, ja...
# 440      frontend  react/redux, angular, vue.js, html, css, javas...
# 441      frontend  advanced react (hooks, redux), angular, vue.js...
# 442      frontend  react/redux, angular, vue.js, html, css, javas...
# 443      frontend  react/redux, angular, vue.js, html, css, javas...
# 444      frontend  react/redux, angular, vue.js, html, css, javas...
#
#                                 clean_Responsibilities
# 100  assist in building server-side applications, d...
# 101  implement scalable backend services, develop a...
# 102  develop and maintain backend apis, optimize da...
# 103  server-side development for web and mobile app...
# 104  design and develop backend services, write eff...
# 105  develop backend modules, assist in api develop...
# 106  assist in developing backend services for web ...
# 107  server-side components for web and mobile apps...
# 108  assist in backend development of scalable apis...
# 109  assist in backend development, develop apis, m...
# 110  design, develop, and maintain backend services...
# 111  lead backend development for fintech applicati...
# 112  architect backend systems for healthcare appli...
# 113  lead backend engineering for e-commerce platfo...
# 114  design backend services for ai-powered applica...
# 115  lead backend infrastructure for logistics plat...
# 116  architect backend solutions for saas applicati...
# 117  develop backend systems for fintech and bankin...
# 118  lead backend development for large-scale socia...
# 119  architect backend solutions for media streamin...
# 300  assist in analyzing datasets, create dashboard...
# 301  perform data extraction and cleaning, create v...
# 302  assist with data cleaning and exploratory data...
# 303  support data extraction and cleaning, generate...
# 304  assist in cleaning datasets, build simple dash...
# 305  support teams in analyzing datasets, perform d...
# 306  assist in etl processes, perform data cleaning...
# 307  perform data cleaning, generate dashboards, as...
# 308  assist teams with sql queries, process data us...
# 309  lead analytics projects, develop predictive mo...
# 310  design and implement advanced analytics soluti...
# 311  lead business intelligence projects, develop p...
# 312  develop advanced dashboards, optimize sql quer...
# 313  lead analytics and bi projects, manage data pi...
# 314  design and implement analytics dashboards, opt...
# 315  lead analytics initiatives, design predictive ...
# 316  manage large-scale analytics projects, impleme...
# 317  design and implement analytics dashboards, opt...
# 318  lead analytics and bi projects, manage data pi...
# 319  manage large-scale analytics projects, impleme...
# 342  assist in data collection, cleaning, and analy...
# 427  build responsive and interactive web pages, im...
# 428  develop web interfaces for internal tools, imp...
# 429  work on small projects and personal applicatio...
# 430  assist in designing and coding responsive web ...
# 431  create and maintain frontend components, parti...
# 432  develop interactive ui pages for internal dash...
# 433  assist in implementing ui features for web app...
# 434  build responsive web pages, assist in integrat...
# 435  assist in creating web interfaces and componen...
# 436  work on academic and personal projects, develo...
# 437  design and develop advanced frontend applicati...
# 438  lead frontend development for scalable applica...
# 439  architect and implement frontend solutions, le...
# 440  lead frontend initiatives for e-commerce platf...
# 441  architect scalable web dashboards and spas, op...
# 442  lead frontend development for saas products, i...
# 443  build and optimize frontend for media streamin...
# 444  lead frontend for ai-powered dashboards, build...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 100 to 444
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   role                    59 non-null     object
#  1   clean_Skills            59 non-null     object
#  2   clean_Responsibilities  59 non-null     object
# dtypes: object(3)
# memory usage: 1.8+ KB

# %%
df_final.rename(columns={'clean_Skills': 'skills', 'clean_Responsibilities': 'description'}, inplace=True)
df_final
# Out:
#              role                                             skills  \
# 100       backend  node.js, python, java, express.js, flask, djan...
# 101       backend  node.js, python, java, express.js, flask, djan...
# 102       backend  node.js, python, express.js, flask, django, my...
# 103       backend  node.js, python, express.js, flask, django, my...
# 104       backend  node.js, python, java, express.js, flask, djan...
# 105       backend  node.js, python, java, express.js, flask, djan...
# 106       backend  node.js, python, express.js, django, flask, my...
# 107       backend  node.js, python, java, express.js, django, fla...
# 108       backend  node.js, python, express.js, flask, django, my...
# 109       backend  node.js, python, java, express.js, django, fla...
# 110       backend  node.js, python, java, go, express.js, django,...
# 111       backend  java, go, node.js, spring boot, express.js, po...
# 112       backend  python, node.js, django, flask, express.js, po...
# 113       backend  node.js, python, java, express.js, django, fla...
# 114       backend  python, node.js, go, django, flask, express.js...
# 115       backend  node.js, java, python, express.js, spring boot...
# 116       backend  python, node.js, java, django, flask, express....
# 117       backend  java, go, python, spring boot, express.js, dja...
# 118       backend  node.js, python, java, express.js, django, spr...
# 119       backend  node.js, python, go, express.js, django, flask...
# 300  data analyst  sql, python, r, sas, tableau, power bi, matplo...
# 301  data analyst  sql, python, r, tableau, power bi, excel chart...
# 302  data analyst  sql, python, r, sas, tableau, power bi, matplo...
# 303  data analyst  sql, python, r, tableau, power bi, excel, pand...
# 304  data analyst  sql, python, r, sas, tableau, power bi, matplo...
# 305  data analyst  sql, python, r, tableau, power bi, matplotlib,...
# 306  data analyst  sql, python, r, tableau, power bi, excel chart...
# 307  data analyst  sql, python, r, tableau, power bi, excel chart...
# 308  data analyst  sql, python, r, sas, tableau, power bi, matplo...
# 309  data analyst  predictive modeling, machine learning algorith...
# 310  data analyst  predictive modeling, machine learning, time-se...
# 311  data analyst  predictive modeling, advanced analytics, machi...
# 312  data analyst  advanced sql, python, r, predictive modeling, ...
# 313  data analyst  predictive modeling, machine learning, advance...
# 314  data analyst  advanced sql, python, r, predictive modeling, ...
# 315  data analyst  advanced sql, python, r, predictive modeling, ...
# 316  data analyst  advanced sql, python, r, sas, predictive model...
# 317  data analyst  advanced sql, python, r, predictive modeling, ...
# 318  data analyst  advanced sql, python, r, predictive modeling, ...
# 319  data analyst  advanced sql, python, r, predictive modeling, ...
# 342  data analyst  python, r, sql, pandas, numpy, matplotlib, sea...
# 427      frontend  html, css, javascript, react basics, angular b...
# 428      frontend  html5, css3, javascript (es6+), react, vue.js,...
# 429      frontend  html, css, javascript, react basics, angular b...
# 430      frontend  html5, css3, javascript (es6+), react basics, ...
# 431      frontend  html, css, javascript, react basics, angular b...
# 432      frontend  html, css, javascript, react basics, angular b...
# 433      frontend  html, css, javascript, react basics, vue.js ba...
# 434      frontend  html, css, javascript, react basics, angular b...
# 435      frontend  html, css, javascript, react basics, vue.js ba...
# 436      frontend  html, css, javascript, react basics, angular b...
# 437      frontend  html5, css3, javascript (es6+), react/redux, a...
# 438      frontend  react/redux, angular, vue.js, html, css, javas...
# 439      frontend  advanced react, angular, vue.js, html, css, ja...
# 440      frontend  react/redux, angular, vue.js, html, css, javas...
# 441      frontend  advanced react (hooks, redux), angular, vue.js...
# 442      frontend  react/redux, angular, vue.js, html, css, javas...
# 443      frontend  react/redux, angular, vue.js, html, css, javas...
# 444      frontend  react/redux, angular, vue.js, html, css, javas...
#
#                                            description
# 100  assist in building server-side applications, d...
# 101  implement scalable backend services, develop a...
# 102  develop and maintain backend apis, optimize da...
# 103  server-side development for web and mobile app...
# 104  design and develop backend services, write eff...
# 105  develop backend modules, assist in api develop...
# 106  assist in developing backend services for web ...
# 107  server-side components for web and mobile apps...
# 108  assist in backend development of scalable apis...
# 109  assist in backend development, develop apis, m...
# 110  design, develop, and maintain backend services...
# 111  lead backend development for fintech applicati...
# 112  architect backend systems for healthcare appli...
# 113  lead backend engineering for e-commerce platfo...
# 114  design backend services for ai-powered applica...
# 115  lead backend infrastructure for logistics plat...
# 116  architect backend solutions for saas applicati...
# 117  develop backend systems for fintech and bankin...
# 118  lead backend development for large-scale socia...
# 119  architect backend solutions for media streamin...
# 300  assist in analyzing datasets, create dashboard...
# 301  perform data extraction and cleaning, create v...
# 302  assist with data cleaning and exploratory data...
# 303  support data extraction and cleaning, generate...
# 304  assist in cleaning datasets, build simple dash...
# 305  support teams in analyzing datasets, perform d...
# 306  assist in etl processes, perform data cleaning...
# 307  perform data cleaning, generate dashboards, as...
# 308  assist teams with sql queries, process data us...
# 309  lead analytics projects, develop predictive mo...
# 310  design and implement advanced analytics soluti...
# 311  lead business intelligence projects, develop p...
# 312  develop advanced dashboards, optimize sql quer...
# 313  lead analytics and bi projects, manage data pi...
# 314  design and implement analytics dashboards, opt...
# 315  lead analytics initiatives, design predictive ...
# 316  manage large-scale analytics projects, impleme...
# 317  design and implement analytics dashboards, opt...
# 318  lead analytics and bi projects, manage data pi...
# 319  manage large-scale analytics projects, impleme...
# 342  assist in data collection, cleaning, and analy...
# 427  build responsive and interactive web pages, im...
# 428  develop web interfaces for internal tools, imp...
# 429  work on small projects and personal applicatio...
# 430  assist in designing and coding responsive web ...
# 431  create and maintain frontend components, parti...
# 432  develop interactive ui pages for internal dash...
# 433  assist in implementing ui features for web app...
# 434  build responsive web pages, assist in integrat...
# 435  assist in creating web interfaces and componen...
# 436  work on academic and personal projects, develo...
# 437  design and develop advanced frontend applicati...
# 438  lead frontend development for scalable applica...
# 439  architect and implement frontend solutions, le...
# 440  lead frontend initiatives for e-commerce platf...
# 441  architect scalable web dashboards and spas, op...
# 442  lead frontend development for saas products, i...
# 443  build and optimize frontend for media streamin...
# 444  lead frontend for ai-powered dashboards, build...

# %%
def preprocessing_lanjutan(text):
    text = text.replace('/', ' ')
    text = text.replace('&', ' ')
    text = re.sub(r"[()]", " ", text)
    
    return text
    
df_final['skills'] = df_final['skills'].apply(preprocessing_lanjutan).copy()
df_final
# Out:
#              role                                             skills  \
# 100       backend  node.js, python, java, express.js, flask, djan...
# 101       backend  node.js, python, java, express.js, flask, djan...
# 102       backend  node.js, python, express.js, flask, django, my...
# 103       backend  node.js, python, express.js, flask, django, my...
# 104       backend  node.js, python, java, express.js, flask, djan...
# 105       backend  node.js, python, java, express.js, flask, djan...
# 106       backend  node.js, python, express.js, django, flask, my...
# 107       backend  node.js, python, java, express.js, django, fla...
# 108       backend  node.js, python, express.js, flask, django, my...
# 109       backend  node.js, python, java, express.js, django, fla...
# 110       backend  node.js, python, java, go, express.js, django,...
# 111       backend  java, go, node.js, spring boot, express.js, po...
# 112       backend  python, node.js, django, flask, express.js, po...
# 113       backend  node.js, python, java, express.js, django, fla...
# 114       backend  python, node.js, go, django, flask, express.js...
# 115       backend  node.js, java, python, express.js, spring boot...
# 116       backend  python, node.js, java, django, flask, express....
# 117       backend  java, go, python, spring boot, express.js, dja...
# 118       backend  node.js, python, java, express.js, django, spr...
# 119       backend  node.js, python, go, express.js, django, flask...
# 300  data analyst  sql, python, r, sas, tableau, power bi, matplo...
# 301  data analyst  sql, python, r, tableau, power bi, excel chart...
# 302  data analyst  sql, python, r, sas, tableau, power bi, matplo...
# 303  data analyst  sql, python, r, tableau, power bi, excel, pand...
# 304  data analyst  sql, python, r, sas, tableau, power bi, matplo...
# 305  data analyst  sql, python, r, tableau, power bi, matplotlib,...
# 306  data analyst  sql, python, r, tableau, power bi, excel chart...
# 307  data analyst  sql, python, r, tableau, power bi, excel chart...
# 308  data analyst  sql, python, r, sas, tableau, power bi, matplo...
# 309  data analyst  predictive modeling, machine learning algorith...
# 310  data analyst  predictive modeling, machine learning, time-se...
# 311  data analyst  predictive modeling, advanced analytics, machi...
# 312  data analyst  advanced sql, python, r, predictive modeling, ...
# 313  data analyst  predictive modeling, machine learning, advance...
# 314  data analyst  advanced sql, python, r, predictive modeling, ...
# 315  data analyst  advanced sql, python, r, predictive modeling, ...
# 316  data analyst  advanced sql, python, r, sas, predictive model...
# 317  data analyst  advanced sql, python, r, predictive modeling, ...
# 318  data analyst  advanced sql, python, r, predictive modeling, ...
# 319  data analyst  advanced sql, python, r, predictive modeling, ...
# 342  data analyst  python, r, sql, pandas, numpy, matplotlib, sea...
# 427      frontend  html, css, javascript, react basics, angular b...
# 428      frontend  html5, css3, javascript  es6+ , react, vue.js,...
# 429      frontend  html, css, javascript, react basics, angular b...
# 430      frontend  html5, css3, javascript  es6+ , react basics, ...
# 431      frontend  html, css, javascript, react basics, angular b...
# 432      frontend  html, css, javascript, react basics, angular b...
# 433      frontend  html, css, javascript, react basics, vue.js ba...
# 434      frontend  html, css, javascript, react basics, angular b...
# 435      frontend  html, css, javascript, react basics, vue.js ba...
# 436      frontend  html, css, javascript, react basics, angular b...
# 437      frontend  html5, css3, javascript  es6+ , react redux, a...
# 438      frontend  react redux, angular, vue.js, html, css, javas...
# 439      frontend  advanced react, angular, vue.js, html, css, ja...
# 440      frontend  react redux, angular, vue.js, html, css, javas...
# 441      frontend  advanced react  hooks, redux , angular, vue.js...
# 442      frontend  react redux, angular, vue.js, html, css, javas...
# 443      frontend  react redux, angular, vue.js, html, css, javas...
# 444      frontend  react redux, angular, vue.js, html, css, javas...
#
#                                            description
# 100  assist in building server-side applications, d...
# 101  implement scalable backend services, develop a...
# 102  develop and maintain backend apis, optimize da...
# 103  server-side development for web and mobile app...
# 104  design and develop backend services, write eff...
# 105  develop backend modules, assist in api develop...
# 106  assist in developing backend services for web ...
# 107  server-side components for web and mobile apps...
# 108  assist in backend development of scalable apis...
# 109  assist in backend development, develop apis, m...
# 110  design, develop, and maintain backend services...
# 111  lead backend development for fintech applicati...
# 112  architect backend systems for healthcare appli...
# 113  lead backend engineering for e-commerce platfo...
# 114  design backend services for ai-powered applica...
# 115  lead backend infrastructure for logistics plat...
# 116  architect backend solutions for saas applicati...
# 117  develop backend systems for fintech and bankin...
# 118  lead backend development for large-scale socia...
# 119  architect backend solutions for media streamin...
# 300  assist in analyzing datasets, create dashboard...
# 301  perform data extraction and cleaning, create v...
# 302  assist with data cleaning and exploratory data...
# 303  support data extraction and cleaning, generate...
# 304  assist in cleaning datasets, build simple dash...
# 305  support teams in analyzing datasets, perform d...
# 306  assist in etl processes, perform data cleaning...
# 307  perform data cleaning, generate dashboards, as...
# 308  assist teams with sql queries, process data us...
# 309  lead analytics projects, develop predictive mo...
# 310  design and implement advanced analytics soluti...
# 311  lead business intelligence projects, develop p...
# 312  develop advanced dashboards, optimize sql quer...
# 313  lead analytics and bi projects, manage data pi...
# 314  design and implement analytics dashboards, opt...
# 315  lead analytics initiatives, design predictive ...
# 316  manage large-scale analytics projects, impleme...
# 317  design and implement analytics dashboards, opt...
# 318  lead analytics and bi projects, manage data pi...
# 319  manage large-scale analytics projects, impleme...
# 342  assist in data collection, cleaning, and analy...
# 427  build responsive and interactive web pages, im...
# 428  develop web interfaces for internal tools, imp...
# 429  work on small projects and personal applicatio...
# 430  assist in designing and coding responsive web ...
# 431  create and maintain frontend components, parti...
# 432  develop interactive ui pages for internal dash...
# 433  assist in implementing ui features for web app...
# 434  build responsive web pages, assist in integrat...
# 435  assist in creating web interfaces and componen...
# 436  work on academic and personal projects, develo...
# 437  design and develop advanced frontend applicati...
# 438  lead frontend development for scalable applica...
# 439  architect and implement frontend solutions, le...
# 440  lead frontend initiatives for e-commerce platf...
# 441  architect scalable web dashboards and spas, op...
# 442  lead frontend development for saas products, i...
# 443  build and optimize frontend for media streamin...
# 444  lead frontend for ai-powered dashboards, build...

# %%
df_final['description'] = df_final['description'].astype(str).str.strip()
df_final
# Out:
#              role                                             skills  \
# 100       backend  node.js, python, java, express.js, flask, djan...
# 101       backend  node.js, python, java, express.js, flask, djan...
# 102       backend  node.js, python, express.js, flask, django, my...
# 103       backend  node.js, python, express.js, flask, django, my...
# 104       backend  node.js, python, java, express.js, flask, djan...
# 105       backend  node.js, python, java, express.js, flask, djan...
# 106       backend  node.js, python, express.js, django, flask, my...
# 107       backend  node.js, python, java, express.js, django, fla...
# 108       backend  node.js, python, express.js, flask, django, my...
# 109       backend  node.js, python, java, express.js, django, fla...
# 110       backend  node.js, python, java, go, express.js, django,...
# 111       backend  java, go, node.js, spring boot, express.js, po...
# 112       backend  python, node.js, django, flask, express.js, po...
# 113       backend  node.js, python, java, express.js, django, fla...
# 114       backend  python, node.js, go, django, flask, express.js...
# 115       backend  node.js, java, python, express.js, spring boot...
# 116       backend  python, node.js, java, django, flask, express....
# 117       backend  java, go, python, spring boot, express.js, dja...
# 118       backend  node.js, python, java, express.js, django, spr...
# 119       backend  node.js, python, go, express.js, django, flask...
# 300  data analyst  sql, python, r, sas, tableau, power bi, matplo...
# 301  data analyst  sql, python, r, tableau, power bi, excel chart...
# 302  data analyst  sql, python, r, sas, tableau, power bi, matplo...
# 303  data analyst  sql, python, r, tableau, power bi, excel, pand...
# 304  data analyst  sql, python, r, sas, tableau, power bi, matplo...
# 305  data analyst  sql, python, r, tableau, power bi, matplotlib,...
# 306  data analyst  sql, python, r, tableau, power bi, excel chart...
# 307  data analyst  sql, python, r, tableau, power bi, excel chart...
# 308  data analyst  sql, python, r, sas, tableau, power bi, matplo...
# 309  data analyst  predictive modeling, machine learning algorith...
# 310  data analyst  predictive modeling, machine learning, time-se...
# 311  data analyst  predictive modeling, advanced analytics, machi...
# 312  data analyst  advanced sql, python, r, predictive modeling, ...
# 313  data analyst  predictive modeling, machine learning, advance...
# 314  data analyst  advanced sql, python, r, predictive modeling, ...
# 315  data analyst  advanced sql, python, r, predictive modeling, ...
# 316  data analyst  advanced sql, python, r, sas, predictive model...
# 317  data analyst  advanced sql, python, r, predictive modeling, ...
# 318  data analyst  advanced sql, python, r, predictive modeling, ...
# 319  data analyst  advanced sql, python, r, predictive modeling, ...
# 342  data analyst  python, r, sql, pandas, numpy, matplotlib, sea...
# 427      frontend  html, css, javascript, react basics, angular b...
# 428      frontend  html5, css3, javascript  es6+ , react, vue.js,...
# 429      frontend  html, css, javascript, react basics, angular b...
# 430      frontend  html5, css3, javascript  es6+ , react basics, ...
# 431      frontend  html, css, javascript, react basics, angular b...
# 432      frontend  html, css, javascript, react basics, angular b...
# 433      frontend  html, css, javascript, react basics, vue.js ba...
# 434      frontend  html, css, javascript, react basics, angular b...
# 435      frontend  html, css, javascript, react basics, vue.js ba...
# 436      frontend  html, css, javascript, react basics, angular b...
# 437      frontend  html5, css3, javascript  es6+ , react redux, a...
# 438      frontend  react redux, angular, vue.js, html, css, javas...
# 439      frontend  advanced react, angular, vue.js, html, css, ja...
# 440      frontend  react redux, angular, vue.js, html, css, javas...
# 441      frontend  advanced react  hooks, redux , angular, vue.js...
# 442      frontend  react redux, angular, vue.js, html, css, javas...
# 443      frontend  react redux, angular, vue.js, html, css, javas...
# 444      frontend  react redux, angular, vue.js, html, css, javas...
#
#                                            description
# 100  assist in building server-side applications, d...
# 101  implement scalable backend services, develop a...
# 102  develop and maintain backend apis, optimize da...
# 103  server-side development for web and mobile app...
# 104  design and develop backend services, write eff...
# 105  develop backend modules, assist in api develop...
# 106  assist in developing backend services for web ...
# 107  server-side components for web and mobile apps...
# 108  assist in backend development of scalable apis...
# 109  assist in backend development, develop apis, m...
# 110  design, develop, and maintain backend services...
# 111  lead backend development for fintech applicati...
# 112  architect backend systems for healthcare appli...
# 113  lead backend engineering for e-commerce platfo...
# 114  design backend services for ai-powered applica...
# 115  lead backend infrastructure for logistics plat...
# 116  architect backend solutions for saas applicati...
# 117  develop backend systems for fintech and bankin...
# 118  lead backend development for large-scale socia...
# 119  architect backend solutions for media streamin...
# 300  assist in analyzing datasets, create dashboard...
# 301  perform data extraction and cleaning, create v...
# 302  assist with data cleaning and exploratory data...
# 303  support data extraction and cleaning, generate...
# 304  assist in cleaning datasets, build simple dash...
# 305  support teams in analyzing datasets, perform d...
# 306  assist in etl processes, perform data cleaning...
# 307  perform data cleaning, generate dashboards, as...
# 308  assist teams with sql queries, process data us...
# 309  lead analytics projects, develop predictive mo...
# 310  design and implement advanced analytics soluti...
# 311  lead business intelligence projects, develop p...
# 312  develop advanced dashboards, optimize sql quer...
# 313  lead analytics and bi projects, manage data pi...
# 314  design and implement analytics dashboards, opt...
# 315  lead analytics initiatives, design predictive ...
# 316  manage large-scale analytics projects, impleme...
# 317  design and implement analytics dashboards, opt...
# 318  lead analytics and bi projects, manage data pi...
# 319  manage large-scale analytics projects, impleme...
# 342  assist in data collection, cleaning, and analy...
# 427  build responsive and interactive web pages, im...
# 428  develop web interfaces for internal tools, imp...
# 429  work on small projects and personal applicatio...
# 430  assist in designing and coding responsive web ...
# 431  create and maintain frontend components, parti...
# 432  develop interactive ui pages for internal dash...
# 433  assist in implementing ui features for web app...
# 434  build responsive web pages, assist in integrat...
# 435  assist in creating web interfaces and componen...
# 436  work on academic and personal projects, develo...
# 437  design and develop advanced frontend applicati...
# 438  lead frontend development for scalable applica...
# 439  architect and implement frontend solutions, le...
# 440  lead frontend initiatives for e-commerce platf...
# 441  architect scalable web dashboards and spas, op...
# 442  lead frontend development for saas products, i...
# 443  build and optimize frontend for media streamin...
# 444  lead frontend for ai-powered dashboards, build...

# %%
df_final.to_csv('data6.csv', index=False)
